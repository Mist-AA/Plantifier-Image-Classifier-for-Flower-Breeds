# %% [markdown]
# # Developing an AI application
#
# Going forward, AI algorithms will be incorporated into more and more everyday applications. For example, you might want to include an image classifier in a smart phone app. To do this, you'd use a deep learning model trained on hundreds of thousands of images as part of the overall application architecture. A large part of software development in the future will be using these types of models as common parts of applications.
#
# In this project, you'll train an image classifier to recognize different species of flowers. You can imagine using something like this in a phone app that tells you the name of the flower your camera is looking at. In practice you'd train this classifier, then export it for use in your application. We'll be using [this dataset](http://www.robots.ox.ac.uk/~vgg/data/flowers/102/index.html) of 102 flower categories, you can see a few examples below.
#
# <img src='assets/Flowers.png' width=500px>
#
# The project is broken down into multiple steps:
#
# * Load and preprocess the image dataset
# * Train the image classifier on your dataset
# * Use the trained classifier to predict image content
#
# We'll lead you through each part which you'll implement in Python.
#
# When you've completed this project, you'll have an application that can be trained on any set of labeled images. Here your network will be learning about flowers and end up as a command line application. But, what you do with your new skills depends on your imagination and effort in building a dataset. For example, imagine an app where you take a picture of a car, it tells you what the make and model is, then looks up information about it. Go build your own dataset and make something new.
#
# First up is importing the packages you'll need. It's good practice to keep all the imports at the beginning of your code. As you work through this notebook and find you need to import a package, make sure to add the import up here.

# %%
#Imports here
import numpy as np
import matplotlib.pyplot as plt
import torch
from torch import nn
from torch import tensor
from torch import optim
import torch.nn.functional as F
from torch.autograd import Variable
from torchvision import datasets, transforms
import torchvision.models as models
import argparse
from collections import OrderedDict
import json
import PIL
import seaborn as sns
from PIL import Image
import time

# %% [markdown]
# ## Load the data
#
# Here you'll use `torchvision` to load the data ([documentation](http://pytorch.org/docs/0.3.0/torchvision/index.html)). The data should be included alongside this notebook, otherwise you can [download it here](https://s3.amazonaws.com/content.udacity-data.com/nd089/flower_data.tar.gz). The dataset is split into three parts, training, validation, and testing. For the training, you'll want to apply transformations such as random scaling, cropping, and flipping. This will help the network generalize leading to better performance. You'll also need to make sure the input data is resized to 224x224 pixels as required by the pre-trained networks.
#
# The validation and testing sets are used to measure the model's performance on data it hasn't seen yet. For this you don't want any scaling or rotation transformations, but you'll need to resize then crop the images to the appropriate size.
#
# The pre-trained networks you'll use were trained on the ImageNet dataset where each color channel was normalized separately. For all three sets you'll need to normalize the means and standard deviations of the images to what the network expects. For the means, it's `[0.485, 0.456, 0.406]` and for the standard deviations `[0.229, 0.224, 0.225]`, calculated from the ImageNet images.  These values will shift each color channel to be centered at 0 and range from -1 to 1.

# %%
data_dir = 'flowers'
train_dir = data_dir + '/train'
valid_dir = data_dir + '/valid'
test_dir = data_dir + '/test'

# %%
# TODO: Define your transforms for the training, validation, and testing sets
data_transforms = {
    'train': transforms.Compose([
        transforms.RandomResizedCrop(size=224),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize([0.485,0.456,0.406],
                            [0.229,0.224,0.225])
    ]),
    'valid': transforms.Compose([
        transforms.Resize(size=256),
        transforms.CenterCrop(size=224),
        transforms.ToTensor(),
        transforms.Normalize([0.485,0.456,0.406],
                            [0.229,0.224,0.225])
    ]),
    'test': transforms.Compose([
        transforms.Resize(size=256),
        transforms.CenterCrop(size=224),
        transforms.ToTensor(),
        transforms.Normalize([0.485,0.456,0.406],
                            [0.229,0.224,0.225])
    ])
}

# TODO: Load the datasets with ImageFolder
image_datasets = {
    'train': datasets.ImageFolder(train_dir, transform=data_transforms['train']),
    'valid': datasets.ImageFolder(valid_dir, transform=data_transforms['valid']),
    'test': datasets.ImageFolder(test_dir, transform=data_transforms['test'])
}

# TODO: Using the image datasets and the trainforms, define the dataloaders
train_loader = torch.utils.data.DataLoader(image_datasets['train'], batch_size=64, shuffle=True)
valid_loader = torch.utils.data.DataLoader(image_datasets['valid'], batch_size=64, shuffle=True)
test_loader = torch.utils.data.DataLoader(image_datasets['test'], batch_size=64, shuffle=True)

# %% [markdown]
# ### Label mapping
#
# You'll also need to load in a mapping from category label to category name. You can find this in the file `cat_to_name.json`. It's a JSON object which you can read in with the [`json` module](https://docs.python.org/2/library/json.html). This will give you a dictionary mapping the integer encoded categories to the actual names of the flowers.

# %%
import json

with open('cat_to_name.json', 'r') as f:
    cat_to_name = json.load(f)

# %% [markdown]
# # Building and training the classifier
#
# Now that the data is ready, it's time to build and train the classifier. As usual, you should use one of the pretrained models from `torchvision.models` to get the image features. Build and train a new feed-forward classifier using those features.
#
# We're going to leave this part up to you. Refer to [the rubric](https://review.udacity.com/#!/rubrics/1663/view) for guidance on successfully completing this section. Things you'll need to do:
#
# * Load a [pre-trained network](http://pytorch.org/docs/master/torchvision/models.html) (If you need a starting point, the VGG networks work great and are straightforward to use)
# * Define a new, untrained feed-forward network as a classifier, using ReLU activations and dropout
# * Train the classifier layers using backpropagation using the pre-trained network to get the features
# * Track the loss and accuracy on the validation set to determine the best hyperparameters
#
# We've left a cell open for you below, but use as many as you need. Our advice is to break the problem up into smaller parts you can run separately. Check that each part is doing what you expect, then move on to the next. You'll likely find that as you work through each part, you'll need to go back and modify your previous code. This is totally normal!
#
# When training make sure you're updating only the weights of the feed-forward network. You should be able to get the validation accuracy above 70% if you build everything right. Make sure to try different hyperparameters (learning rate, units in the classifier, epochs, etc) to find the best model. Save those hyperparameters to use as default values in the next part of the project.
#
# One last important tip if you're using the workspace to run your code: To avoid having your workspace disconnect during the long-running tasks in this notebook, please read in the earlier page in this lesson called Intro to
# GPU Workspaces about Keeping Your Session Active. You'll want to include code from the workspace_utils.py module.
#
# <font color='red'>**Note for Workspace users:** If your network is over 1 GB when saved as a checkpoint, there might be issues with saving backups in your workspace. Typically this happens with wide dense layers after the convolutional layers. If your saved checkpoint is larger than 1 GB (you can open a terminal and check with `ls -lh`), you should reduce the size of your hidden layers and train again.</font>

# %%
# TODO: Build and train your network

#Loading pretrained vgg16 model since it performs well 
model = models.vgg16(pretrained=True)

#Freeze parameters of pre-trained model
for param in model.parameters():
    param.requires_grad = False

#Defining Custom Classifier
classifier = nn.Sequential(OrderedDict([
    ('inputs', nn.Linear(25088, 120)),
    ('relu1', nn.ReLU()),
    ('dropout', nn.Dropout(0.5)),
    ('hidden_layer1', nn.Linear(120, 90)),
    ('relu2', nn.ReLU()),
    ('hidden_layer2', nn.Linear(90, 70)),
    ('relu3', nn.ReLU()),
    ('hidden_layer3', nn.Linear(70,102)),
    ('output', nn.LogSoftmax(dim=1))
]))

#Replacing classifier of the pretrained model
model.classifier = classifier

#Check for gpu else run on cpu
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)

#Defining loss function and optimizer
criterion = nn.NLLLoss()
optimizer = optim.Adam(model.classifier.parameters(), lr=0.001)

#testing for later model loading
# Out:
# Downloading: "https://download.pytorch.org/models/vgg16-397923af.pth" to /root/.torch/models/vgg16-397923af.pth
# 100%|██████████| 553433881/553433881 [00:04<00:00, 112463081.46it/s]

# %%
print(model)
# Out:
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace)
#     (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): ReLU(inplace)
#     (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU(inplace)
#     (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU(inplace)
#     (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (25): ReLU(inplace)
#     (26): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (27): ReLU(inplace)
#     (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (29): ReLU(inplace)
#     (30): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (inputs): Linear(in_features=25088, out_features=120, bias=True)
#     (relu1): ReLU()
#     (dropout): Dropout(p=0.5)
#     (hidden_layer1): Linear(in_features=120, out_features=90, bias=True)
#     (relu2): ReLU()
#     (hidden_layer2): Linear(in_features=90, out_features=70, bias=True)
#     (relu3): ReLU()
#     (hidden_layer3): Linear(in_features=70, out_features=102, bias=True)
#     (output): LogSoftmax()
#   )
# )

# %%
num_epochs = 16

for epoch in range(num_epochs):
    print("Epoch: {}/{}".format(epoch+1, num_epochs))
    
    model.train()
    train_loss = 0.0
    train_acc = 0.0
    valid_loss = 0.0
    valid_acc = 0.0
    
    for batch_idx, (datas, target) in enumerate(train_loader):
        datas = datas.to(device)
        target = target.to(device)
        
        optimizer.zero_grad()
        
        outputs = model(datas)
        loss = criterion(outputs, target)
        loss.backward()
        optimizer.step()
        
        train_loss += loss.item() * datas.size(0)
        
        _, predictions = torch.max(outputs.data, 1)
        correct_counts = predictions.eq(target.data.view_as(predictions))
        
        batch_acc = torch.mean(correct_counts.type(torch.FloatTensor))
        train_acc += batch_acc.item() * datas.size(0)
        
        print("Batch number: {:03d}, Loss on training: {:.4f}, Accuracy: {:.4f}".format(batch_idx, loss.item(), batch_acc.item()))
# Out:
# Epoch: 1/16
# Batch number: 000, Loss on training: 4.6091, Accuracy: 0.0156
# Batch number: 001, Loss on training: 4.6116, Accuracy: 0.0000
# Batch number: 002, Loss on training: 4.5501, Accuracy: 0.0156
# Batch number: 003, Loss on training: 4.7115, Accuracy: 0.0000
# Batch number: 004, Loss on training: 4.6245, Accuracy: 0.0000
# Batch number: 005, Loss on training: 4.7081, Accuracy: 0.0000
# Batch number: 006, Loss on training: 4.6749, Accuracy: 0.0000
# Batch number: 007, Loss on training: 4.6428, Accuracy: 0.0000
# Batch number: 008, Loss on training: 4.6396, Accuracy: 0.0312
# Batch number: 009, Loss on training: 4.4982, Accuracy: 0.0625
# Batch number: 010, Loss on training: 4.5727, Accuracy: 0.0312
# Batch number: 011, Loss on training: 4.4911, Accuracy: 0.0781
# Batch number: 012, Loss on training: 4.5160, Accuracy: 0.0938
# Batch number: 013, Loss on training: 4.5861, Accuracy: 0.0156
# Batch number: 014, Loss on training: 4.5377, Accuracy: 0.0312
# Batch number: 015, Loss on training: 4.4936, Accuracy: 0.0156
# Batch number: 016, Loss on training: 4.5069, Accuracy: 0.0312
# Batch number: 017, Loss on training: 4.4710, Accuracy: 0.0625
# Batch number: 018, Loss on training: 4.5394, Accuracy: 0.0312
# Batch number: 019, Loss on training: 4.4647, Accuracy: 0.0312
# Batch number: 020, Loss on training: 4.3596, Accuracy: 0.0625
# Batch number: 021, Loss on training: 4.4372, Accuracy: 0.0781
# Batch number: 022, Loss on training: 4.5344, Accuracy: 0.0625
# Batch number: 023, Loss on training: 4.4094, Accuracy: 0.0781
# Batch number: 024, Loss on training: 4.4883, Accuracy: 0.0781
# Batch number: 025, Loss on training: 4.4017, Accuracy: 0.0781
# Batch number: 026, Loss on training: 4.4323, Accuracy: 0.0625
# Batch number: 027, Loss on training: 4.4613, Accuracy: 0.0781
# Batch number: 028, Loss on training: 4.5084, Accuracy: 0.0469
# Batch number: 029, Loss on training: 4.2385, Accuracy: 0.0938
# Batch number: 030, Loss on training: 4.3056, Accuracy: 0.0938
# Batch number: 031, Loss on training: 4.1770, Accuracy: 0.1719
# Batch number: 032, Loss on training: 4.2976, Accuracy: 0.1094
# Batch number: 033, Loss on training: 4.2306, Accuracy: 0.0625
# Batch number: 034, Loss on training: 4.2059, Accuracy: 0.1250
# Batch number: 035, Loss on training: 4.0041, Accuracy: 0.1094
# Batch number: 036, Loss on training: 4.3054, Accuracy: 0.1094
# Batch number: 037, Loss on training: 3.9412, Accuracy: 0.1250
# Batch number: 038, Loss on training: 4.1399, Accuracy: 0.1250
# Batch number: 039, Loss on training: 3.9987, Accuracy: 0.1406
# Batch number: 040, Loss on training: 4.2816, Accuracy: 0.1094
# Batch number: 041, Loss on training: 4.3442, Accuracy: 0.0469
# Batch number: 042, Loss on training: 4.2811, Accuracy: 0.0938
# Batch number: 043, Loss on training: 4.0795, Accuracy: 0.1719
# Batch number: 044, Loss on training: 3.9092, Accuracy: 0.1875
# Batch number: 045, Loss on training: 4.1755, Accuracy: 0.0625
# Batch number: 046, Loss on training: 4.3581, Accuracy: 0.0469
# Batch number: 047, Loss on training: 3.9241, Accuracy: 0.0938
# Batch number: 048, Loss on training: 4.0173, Accuracy: 0.1406
# Batch number: 049, Loss on training: 3.9835, Accuracy: 0.1406
# Batch number: 050, Loss on training: 3.9935, Accuracy: 0.1406
# Batch number: 051, Loss on training: 3.8944, Accuracy: 0.1250
# Batch number: 052, Loss on training: 3.5830, Accuracy: 0.2188
# Batch number: 053, Loss on training: 3.8666, Accuracy: 0.1719
# Batch number: 054, Loss on training: 4.1723, Accuracy: 0.1562
# Batch number: 055, Loss on training: 4.0707, Accuracy: 0.1719
# Batch number: 056, Loss on training: 3.7652, Accuracy: 0.1562
# Batch number: 057, Loss on training: 4.0136, Accuracy: 0.1719
# Batch number: 058, Loss on training: 3.8617, Accuracy: 0.1719
# Batch number: 059, Loss on training: 3.9522, Accuracy: 0.1406
# Batch number: 060, Loss on training: 3.9254, Accuracy: 0.1562
# Batch number: 061, Loss on training: 3.5426, Accuracy: 0.1875
# Batch number: 062, Loss on training: 3.8963, Accuracy: 0.1406
# Batch number: 063, Loss on training: 3.8733, Accuracy: 0.1562
# Batch number: 064, Loss on training: 3.8381, Accuracy: 0.1562
# Batch number: 065, Loss on training: 3.8957, Accuracy: 0.1406
# Batch number: 066, Loss on training: 3.2907, Accuracy: 0.2656
# Batch number: 067, Loss on training: 3.7618, Accuracy: 0.1562
# Batch number: 068, Loss on training: 3.9693, Accuracy: 0.1250
# Batch number: 069, Loss on training: 3.8137, Accuracy: 0.1094
# Batch number: 070, Loss on training: 3.7460, Accuracy: 0.1562
# Batch number: 071, Loss on training: 3.7362, Accuracy: 0.1875
# Batch number: 072, Loss on training: 3.6376, Accuracy: 0.1562
# Batch number: 073, Loss on training: 3.6253, Accuracy: 0.1719
# Batch number: 074, Loss on training: 3.7114, Accuracy: 0.1719
# Batch number: 075, Loss on training: 3.7686, Accuracy: 0.1719
# Batch number: 076, Loss on training: 3.4428, Accuracy: 0.1875
# Batch number: 077, Loss on training: 3.3313, Accuracy: 0.2812
# Batch number: 078, Loss on training: 3.2454, Accuracy: 0.2344
# Batch number: 079, Loss on training: 3.4629, Accuracy: 0.1562
# Batch number: 080, Loss on training: 4.0469, Accuracy: 0.0625
# Batch number: 081, Loss on training: 3.1174, Accuracy: 0.2812
# Batch number: 082, Loss on training: 3.4065, Accuracy: 0.2969
# Batch number: 083, Loss on training: 3.6150, Accuracy: 0.1406
# Batch number: 084, Loss on training: 3.1205, Accuracy: 0.2969
# Batch number: 085, Loss on training: 3.5788, Accuracy: 0.1094
# Batch number: 086, Loss on training: 3.5371, Accuracy: 0.1875
# Batch number: 087, Loss on training: 3.3688, Accuracy: 0.2812
# Batch number: 088, Loss on training: 3.1056, Accuracy: 0.2344
# Batch number: 089, Loss on training: 3.2968, Accuracy: 0.1875
# Batch number: 090, Loss on training: 3.1631, Accuracy: 0.2188
# Batch number: 091, Loss on training: 3.5303, Accuracy: 0.1250
# Batch number: 092, Loss on training: 3.4304, Accuracy: 0.1875
# Batch number: 093, Loss on training: 3.4155, Accuracy: 0.1562
# Batch number: 094, Loss on training: 3.3768, Accuracy: 0.1875
# Batch number: 095, Loss on training: 3.2269, Accuracy: 0.2344
# Batch number: 096, Loss on training: 3.2954, Accuracy: 0.2188
# Batch number: 097, Loss on training: 3.3907, Accuracy: 0.2344
# Batch number: 098, Loss on training: 3.1156, Accuracy: 0.2500
# Batch number: 099, Loss on training: 3.0392, Accuracy: 0.2656
# Batch number: 100, Loss on training: 3.1475, Accuracy: 0.1875
# Batch number: 101, Loss on training: 2.9533, Accuracy: 0.2812
# Batch number: 102, Loss on training: 3.5516, Accuracy: 0.1667
# Epoch: 2/16
# Batch number: 000, Loss on training: 3.0311, Accuracy: 0.2031
# Batch number: 001, Loss on training: 3.0420, Accuracy: 0.3125
# Batch number: 002, Loss on training: 3.3676, Accuracy: 0.2500
# Batch number: 003, Loss on training: 3.0641, Accuracy: 0.2344
# Batch number: 004, Loss on training: 3.0282, Accuracy: 0.2031
# Batch number: 005, Loss on training: 3.1676, Accuracy: 0.3125
# Batch number: 006, Loss on training: 2.9025, Accuracy: 0.2969
# Batch number: 007, Loss on training: 2.9458, Accuracy: 0.2969
# Batch number: 008, Loss on training: 3.1830, Accuracy: 0.2031
# Batch number: 009, Loss on training: 3.3295, Accuracy: 0.1875
# Batch number: 010, Loss on training: 3.0715, Accuracy: 0.2969
# Batch number: 011, Loss on training: 3.0729, Accuracy: 0.1875
# Batch number: 012, Loss on training: 3.1857, Accuracy: 0.2344
# Batch number: 013, Loss on training: 2.8308, Accuracy: 0.2188
# Batch number: 014, Loss on training: 2.9779, Accuracy: 0.3438
# Batch number: 015, Loss on training: 2.9669, Accuracy: 0.2500
# Batch number: 016, Loss on training: 3.0834, Accuracy: 0.2344
# Batch number: 017, Loss on training: 3.1528, Accuracy: 0.1719
# Batch number: 018, Loss on training: 3.2150, Accuracy: 0.2031
# Batch number: 019, Loss on training: 2.7809, Accuracy: 0.2969
# Batch number: 020, Loss on training: 2.5835, Accuracy: 0.2969
# Batch number: 021, Loss on training: 2.9483, Accuracy: 0.2812
# Batch number: 022, Loss on training: 2.6743, Accuracy: 0.3750
# Batch number: 023, Loss on training: 2.7691, Accuracy: 0.3281
# Batch number: 024, Loss on training: 2.9879, Accuracy: 0.3125
# Batch number: 025, Loss on training: 3.0626, Accuracy: 0.2656
# Batch number: 026, Loss on training: 2.9300, Accuracy: 0.2969
# Batch number: 027, Loss on training: 3.0698, Accuracy: 0.2344
# Batch number: 028, Loss on training: 2.8929, Accuracy: 0.2656
# Batch number: 029, Loss on training: 2.8598, Accuracy: 0.2656
# Batch number: 030, Loss on training: 2.8235, Accuracy: 0.2500
# Batch number: 031, Loss on training: 2.9389, Accuracy: 0.2812
# Batch number: 032, Loss on training: 2.5339, Accuracy: 0.3906
# Batch number: 033, Loss on training: 2.8717, Accuracy: 0.2656
# Batch number: 034, Loss on training: 2.7563, Accuracy: 0.2656
# Batch number: 035, Loss on training: 2.8759, Accuracy: 0.2656
# Batch number: 036, Loss on training: 2.7210, Accuracy: 0.3594
# Batch number: 037, Loss on training: 3.0347, Accuracy: 0.2500
# Batch number: 038, Loss on training: 2.6647, Accuracy: 0.3594
# Batch number: 039, Loss on training: 2.4657, Accuracy: 0.3750
# Batch number: 040, Loss on training: 2.6684, Accuracy: 0.3594
# Batch number: 041, Loss on training: 2.5861, Accuracy: 0.2656
# Batch number: 042, Loss on training: 2.9132, Accuracy: 0.2500
# Batch number: 043, Loss on training: 2.7014, Accuracy: 0.3125
# Batch number: 044, Loss on training: 2.8929, Accuracy: 0.2812
# Batch number: 045, Loss on training: 2.6406, Accuracy: 0.3438
# Batch number: 046, Loss on training: 2.7809, Accuracy: 0.2656
# Batch number: 047, Loss on training: 2.7910, Accuracy: 0.2656
# Batch number: 048, Loss on training: 2.9250, Accuracy: 0.2344
# Batch number: 049, Loss on training: 2.8264, Accuracy: 0.3125
# Batch number: 050, Loss on training: 2.6168, Accuracy: 0.3281
# Batch number: 051, Loss on training: 2.4918, Accuracy: 0.3438
# Batch number: 052, Loss on training: 2.4307, Accuracy: 0.3750
# Batch number: 053, Loss on training: 2.6805, Accuracy: 0.3125
# Batch number: 054, Loss on training: 2.3326, Accuracy: 0.4219
# Batch number: 055, Loss on training: 2.7459, Accuracy: 0.3281
# Batch number: 056, Loss on training: 2.9578, Accuracy: 0.2656
# Batch number: 057, Loss on training: 2.6132, Accuracy: 0.3125
# Batch number: 058, Loss on training: 2.2874, Accuracy: 0.3906
# Batch number: 059, Loss on training: 2.4598, Accuracy: 0.3438
# Batch number: 060, Loss on training: 2.7259, Accuracy: 0.2656
# Batch number: 061, Loss on training: 2.8199, Accuracy: 0.2969
# Batch number: 062, Loss on training: 2.9819, Accuracy: 0.2812
# Batch number: 063, Loss on training: 2.7270, Accuracy: 0.2969
# Batch number: 064, Loss on training: 2.7926, Accuracy: 0.3125
# Batch number: 065, Loss on training: 2.8702, Accuracy: 0.2188
# Batch number: 066, Loss on training: 2.3531, Accuracy: 0.3438
# Batch number: 067, Loss on training: 2.7561, Accuracy: 0.3594
# Batch number: 068, Loss on training: 2.7014, Accuracy: 0.2344
# Batch number: 069, Loss on training: 2.6394, Accuracy: 0.3125
# Batch number: 070, Loss on training: 2.8690, Accuracy: 0.2812
# Batch number: 071, Loss on training: 3.0573, Accuracy: 0.2344
# Batch number: 072, Loss on training: 2.7123, Accuracy: 0.3125
# Batch number: 073, Loss on training: 2.5775, Accuracy: 0.2969
# Batch number: 074, Loss on training: 2.5346, Accuracy: 0.3281
# Batch number: 075, Loss on training: 2.7208, Accuracy: 0.2812
# Batch number: 076, Loss on training: 2.2391, Accuracy: 0.4219
# Batch number: 077, Loss on training: 2.3581, Accuracy: 0.2969
# Batch number: 078, Loss on training: 2.7866, Accuracy: 0.3125
# Batch number: 079, Loss on training: 2.5639, Accuracy: 0.2812
# Batch number: 080, Loss on training: 2.6497, Accuracy: 0.3281
# Batch number: 081, Loss on training: 2.5853, Accuracy: 0.3438
# Batch number: 082, Loss on training: 2.4927, Accuracy: 0.3594
# Batch number: 083, Loss on training: 2.6042, Accuracy: 0.3281
# Batch number: 084, Loss on training: 2.7113, Accuracy: 0.3594
# Batch number: 085, Loss on training: 2.3216, Accuracy: 0.3750
# Batch number: 086, Loss on training: 2.5781, Accuracy: 0.3281
# Batch number: 087, Loss on training: 2.9250, Accuracy: 0.2812
# Batch number: 088, Loss on training: 2.5377, Accuracy: 0.2500
# Batch number: 089, Loss on training: 2.2738, Accuracy: 0.3594
# Batch number: 090, Loss on training: 2.6003, Accuracy: 0.3438
# Batch number: 091, Loss on training: 2.6448, Accuracy: 0.2500
# Batch number: 092, Loss on training: 2.9860, Accuracy: 0.2344
# Batch number: 093, Loss on training: 2.5403, Accuracy: 0.2656
# Batch number: 094, Loss on training: 2.4521, Accuracy: 0.3594
# Batch number: 095, Loss on training: 2.4327, Accuracy: 0.2969
# Batch number: 096, Loss on training: 2.4426, Accuracy: 0.3438
# Batch number: 097, Loss on training: 2.3920, Accuracy: 0.3906
# Batch number: 098, Loss on training: 2.3208, Accuracy: 0.3906
# Batch number: 099, Loss on training: 2.6944, Accuracy: 0.2344
# Batch number: 100, Loss on training: 2.6110, Accuracy: 0.3125
# Batch number: 101, Loss on training: 2.5994, Accuracy: 0.3438
# Batch number: 102, Loss on training: 2.7947, Accuracy: 0.2917
# Epoch: 3/16
# Batch number: 000, Loss on training: 2.2713, Accuracy: 0.2812
# Batch number: 001, Loss on training: 2.4422, Accuracy: 0.3594
# Batch number: 002, Loss on training: 2.4481, Accuracy: 0.4062
# Batch number: 003, Loss on training: 2.3576, Accuracy: 0.3594
# Batch number: 004, Loss on training: 2.5222, Accuracy: 0.3438
# Batch number: 005, Loss on training: 2.3366, Accuracy: 0.3125
# Batch number: 006, Loss on training: 2.2402, Accuracy: 0.4375
# Batch number: 007, Loss on training: 2.1460, Accuracy: 0.3750
# Batch number: 008, Loss on training: 2.3508, Accuracy: 0.3750
# Batch number: 009, Loss on training: 2.5349, Accuracy: 0.3438
# Batch number: 010, Loss on training: 2.3613, Accuracy: 0.4531
# Batch number: 011, Loss on training: 2.2262, Accuracy: 0.4531
# Batch number: 012, Loss on training: 2.7979, Accuracy: 0.2969
# Batch number: 013, Loss on training: 2.3031, Accuracy: 0.4531
# Batch number: 014, Loss on training: 2.0629, Accuracy: 0.3906
# Batch number: 015, Loss on training: 2.6014, Accuracy: 0.2344
# Batch number: 016, Loss on training: 2.0173, Accuracy: 0.4844
# Batch number: 017, Loss on training: 2.2850, Accuracy: 0.3594
# Batch number: 018, Loss on training: 2.2945, Accuracy: 0.2969
# Batch number: 019, Loss on training: 2.4559, Accuracy: 0.3438
# Batch number: 020, Loss on training: 2.3289, Accuracy: 0.2969
# Batch number: 021, Loss on training: 2.1036, Accuracy: 0.4375
# Batch number: 022, Loss on training: 2.6060, Accuracy: 0.4062
# Batch number: 023, Loss on training: 2.3018, Accuracy: 0.3281
# Batch number: 024, Loss on training: 2.6430, Accuracy: 0.3594
# Batch number: 025, Loss on training: 2.0052, Accuracy: 0.4688
# Batch number: 026, Loss on training: 2.4905, Accuracy: 0.3281
# Batch number: 027, Loss on training: 2.4806, Accuracy: 0.3594
# Batch number: 028, Loss on training: 2.0273, Accuracy: 0.4375
# Batch number: 029, Loss on training: 2.6336, Accuracy: 0.3750
# Batch number: 030, Loss on training: 2.5160, Accuracy: 0.2969
# Batch number: 031, Loss on training: 2.2719, Accuracy: 0.3281
# Batch number: 032, Loss on training: 2.3702, Accuracy: 0.4219
# Batch number: 033, Loss on training: 2.0858, Accuracy: 0.4844
# Batch number: 034, Loss on training: 1.9828, Accuracy: 0.3594
# Batch number: 035, Loss on training: 2.6937, Accuracy: 0.3594
# Batch number: 036, Loss on training: 2.5881, Accuracy: 0.3125
# Batch number: 037, Loss on training: 2.2258, Accuracy: 0.4062
# Batch number: 038, Loss on training: 1.8593, Accuracy: 0.4688
# Batch number: 039, Loss on training: 2.5927, Accuracy: 0.3438
# Batch number: 040, Loss on training: 2.5017, Accuracy: 0.3594
# Batch number: 041, Loss on training: 2.2108, Accuracy: 0.3906
# Batch number: 042, Loss on training: 2.2301, Accuracy: 0.3750
# Batch number: 043, Loss on training: 2.2992, Accuracy: 0.3594
# Batch number: 044, Loss on training: 2.3806, Accuracy: 0.3438
# Batch number: 045, Loss on training: 2.3613, Accuracy: 0.3750
# Batch number: 046, Loss on training: 1.7268, Accuracy: 0.5469
# Batch number: 047, Loss on training: 2.1810, Accuracy: 0.4062
# Batch number: 048, Loss on training: 1.9772, Accuracy: 0.4219
# Batch number: 049, Loss on training: 2.1174, Accuracy: 0.4219
# Batch number: 050, Loss on training: 1.8443, Accuracy: 0.5000
# Batch number: 051, Loss on training: 2.4758, Accuracy: 0.3750
# Batch number: 052, Loss on training: 2.5443, Accuracy: 0.3125
# Batch number: 053, Loss on training: 2.3428, Accuracy: 0.4531
# Batch number: 054, Loss on training: 2.4798, Accuracy: 0.3906
# Batch number: 055, Loss on training: 2.1764, Accuracy: 0.4062
# Batch number: 056, Loss on training: 2.3302, Accuracy: 0.4219
# Batch number: 057, Loss on training: 2.2644, Accuracy: 0.3594
# Batch number: 058, Loss on training: 2.5277, Accuracy: 0.3281
# Batch number: 059, Loss on training: 2.1035, Accuracy: 0.4375
# Batch number: 060, Loss on training: 2.2524, Accuracy: 0.3906
# Batch number: 061, Loss on training: 2.1165, Accuracy: 0.4375
# Batch number: 062, Loss on training: 1.7641, Accuracy: 0.5000
# Batch number: 063, Loss on training: 2.2929, Accuracy: 0.3750
# Batch number: 064, Loss on training: 2.3046, Accuracy: 0.3594
# Batch number: 065, Loss on training: 2.1380, Accuracy: 0.4219
# Batch number: 066, Loss on training: 2.4632, Accuracy: 0.3594
# Batch number: 067, Loss on training: 2.3018, Accuracy: 0.3438
# Batch number: 068, Loss on training: 2.5443, Accuracy: 0.3750
# Batch number: 069, Loss on training: 2.0352, Accuracy: 0.4688
# Batch number: 070, Loss on training: 2.2949, Accuracy: 0.3906
# Batch number: 071, Loss on training: 2.5117, Accuracy: 0.4219
# Batch number: 072, Loss on training: 2.0330, Accuracy: 0.4375
# Batch number: 073, Loss on training: 2.3298, Accuracy: 0.4375
# Batch number: 074, Loss on training: 2.1980, Accuracy: 0.4062
# Batch number: 075, Loss on training: 2.1097, Accuracy: 0.4375
# Batch number: 076, Loss on training: 2.4975, Accuracy: 0.3594
# Batch number: 077, Loss on training: 2.8938, Accuracy: 0.2969
# Batch number: 078, Loss on training: 2.2109, Accuracy: 0.3281
# Batch number: 079, Loss on training: 2.5572, Accuracy: 0.3281
# Batch number: 080, Loss on training: 2.3121, Accuracy: 0.4062
# Batch number: 081, Loss on training: 2.5137, Accuracy: 0.4219
# Batch number: 082, Loss on training: 2.2290, Accuracy: 0.4688
# Batch number: 083, Loss on training: 2.2856, Accuracy: 0.3906
# Batch number: 084, Loss on training: 2.5055, Accuracy: 0.2969
# Batch number: 085, Loss on training: 2.4110, Accuracy: 0.3438
# Batch number: 086, Loss on training: 2.2219, Accuracy: 0.3281
# Batch number: 087, Loss on training: 2.5023, Accuracy: 0.2812
# Batch number: 088, Loss on training: 2.1802, Accuracy: 0.4375
# Batch number: 089, Loss on training: 2.2695, Accuracy: 0.3750
# Batch number: 090, Loss on training: 2.5040, Accuracy: 0.3906
# Batch number: 091, Loss on training: 2.3530, Accuracy: 0.4688
# Batch number: 092, Loss on training: 1.9502, Accuracy: 0.5000
# Batch number: 093, Loss on training: 2.4750, Accuracy: 0.3750
# Batch number: 094, Loss on training: 2.1965, Accuracy: 0.4062
# Batch number: 095, Loss on training: 2.0900, Accuracy: 0.4062
# Batch number: 096, Loss on training: 2.2629, Accuracy: 0.3438
# Batch number: 097, Loss on training: 2.2882, Accuracy: 0.3125
# Batch number: 098, Loss on training: 1.9654, Accuracy: 0.4375
# Batch number: 099, Loss on training: 2.3558, Accuracy: 0.2969
# Batch number: 100, Loss on training: 2.0370, Accuracy: 0.3594
# Batch number: 101, Loss on training: 2.2415, Accuracy: 0.3594
# Batch number: 102, Loss on training: 2.1824, Accuracy: 0.3750
# Epoch: 4/16
# Batch number: 000, Loss on training: 2.1222, Accuracy: 0.3125
# Batch number: 001, Loss on training: 2.0169, Accuracy: 0.4219
# Batch number: 002, Loss on training: 2.6730, Accuracy: 0.3438
# Batch number: 003, Loss on training: 2.3489, Accuracy: 0.3594
# Batch number: 004, Loss on training: 2.0594, Accuracy: 0.4219
# Batch number: 005, Loss on training: 1.5878, Accuracy: 0.5312
# Batch number: 006, Loss on training: 2.4493, Accuracy: 0.3438
# Batch number: 007, Loss on training: 1.7302, Accuracy: 0.5156
# Batch number: 008, Loss on training: 1.8384, Accuracy: 0.4375
# Batch number: 009, Loss on training: 2.1423, Accuracy: 0.4688
# Batch number: 010, Loss on training: 2.3227, Accuracy: 0.4062
# Batch number: 011, Loss on training: 2.0232, Accuracy: 0.3750
# Batch number: 012, Loss on training: 2.1573, Accuracy: 0.4062
# Batch number: 013, Loss on training: 2.0519, Accuracy: 0.5000
# Batch number: 014, Loss on training: 2.0432, Accuracy: 0.4219
# Batch number: 015, Loss on training: 1.8890, Accuracy: 0.4375
# Batch number: 016, Loss on training: 2.2541, Accuracy: 0.3594
# Batch number: 017, Loss on training: 2.4587, Accuracy: 0.3594
# Batch number: 018, Loss on training: 2.1187, Accuracy: 0.4375
# Batch number: 019, Loss on training: 1.9822, Accuracy: 0.4531
# Batch number: 020, Loss on training: 2.2752, Accuracy: 0.4062
# Batch number: 021, Loss on training: 2.1485, Accuracy: 0.3906
# Batch number: 022, Loss on training: 2.1177, Accuracy: 0.4219
# Batch number: 023, Loss on training: 2.2907, Accuracy: 0.2969
# Batch number: 024, Loss on training: 2.1841, Accuracy: 0.4688
# Batch number: 025, Loss on training: 2.1684, Accuracy: 0.3594
# Batch number: 026, Loss on training: 1.9791, Accuracy: 0.4844
# Batch number: 027, Loss on training: 1.6882, Accuracy: 0.5781
# Batch number: 028, Loss on training: 2.2164, Accuracy: 0.3750
# Batch number: 029, Loss on training: 2.0142, Accuracy: 0.3906
# Batch number: 030, Loss on training: 2.4558, Accuracy: 0.2969
# Batch number: 031, Loss on training: 2.0478, Accuracy: 0.4219
# Batch number: 032, Loss on training: 2.1618, Accuracy: 0.4219
# Batch number: 033, Loss on training: 2.3325, Accuracy: 0.3750
# Batch number: 034, Loss on training: 1.8928, Accuracy: 0.4375
# Batch number: 035, Loss on training: 2.5484, Accuracy: 0.2812
# Batch number: 036, Loss on training: 2.1428, Accuracy: 0.4062
# Batch number: 037, Loss on training: 1.8206, Accuracy: 0.5469
# Batch number: 038, Loss on training: 2.0427, Accuracy: 0.3906
# Batch number: 039, Loss on training: 1.7792, Accuracy: 0.5312
# Batch number: 040, Loss on training: 1.9919, Accuracy: 0.5000
# Batch number: 041, Loss on training: 1.8737, Accuracy: 0.5156
# Batch number: 042, Loss on training: 2.4379, Accuracy: 0.3906
# Batch number: 043, Loss on training: 2.1273, Accuracy: 0.4062
# Batch number: 044, Loss on training: 2.1167, Accuracy: 0.3750
# Batch number: 045, Loss on training: 2.2531, Accuracy: 0.3906
# Batch number: 046, Loss on training: 2.4342, Accuracy: 0.3594
# Batch number: 047, Loss on training: 2.0440, Accuracy: 0.3906
# Batch number: 048, Loss on training: 2.6888, Accuracy: 0.3750
# Batch number: 049, Loss on training: 2.2630, Accuracy: 0.4375
# Batch number: 050, Loss on training: 1.8046, Accuracy: 0.5156
# Batch number: 051, Loss on training: 2.1171, Accuracy: 0.4219
# Batch number: 052, Loss on training: 1.7882, Accuracy: 0.4688
# Batch number: 053, Loss on training: 2.0987, Accuracy: 0.4062
# Batch number: 054, Loss on training: 2.4256, Accuracy: 0.3750
# Batch number: 055, Loss on training: 1.6484, Accuracy: 0.6094
# Batch number: 056, Loss on training: 1.8744, Accuracy: 0.5469
# Batch number: 057, Loss on training: 2.0640, Accuracy: 0.3750
# Batch number: 058, Loss on training: 2.0790, Accuracy: 0.4844
# Batch number: 059, Loss on training: 1.8758, Accuracy: 0.4375
# Batch number: 060, Loss on training: 1.9515, Accuracy: 0.4688
# Batch number: 061, Loss on training: 1.8146, Accuracy: 0.4844
# Batch number: 062, Loss on training: 2.0166, Accuracy: 0.4375
# Batch number: 063, Loss on training: 2.1875, Accuracy: 0.4062
# Batch number: 064, Loss on training: 2.0921, Accuracy: 0.4062
# Batch number: 065, Loss on training: 2.0850, Accuracy: 0.4844
# Batch number: 066, Loss on training: 2.1697, Accuracy: 0.4531
# Batch number: 067, Loss on training: 1.7418, Accuracy: 0.4844
# Batch number: 068, Loss on training: 2.0275, Accuracy: 0.4219
# Batch number: 069, Loss on training: 1.9444, Accuracy: 0.5156
# Batch number: 070, Loss on training: 2.1974, Accuracy: 0.4531
# Batch number: 071, Loss on training: 2.1403, Accuracy: 0.3594
# Batch number: 072, Loss on training: 2.0676, Accuracy: 0.4531
# Batch number: 073, Loss on training: 2.0964, Accuracy: 0.4219
# Batch number: 074, Loss on training: 1.9309, Accuracy: 0.4844
# Batch number: 075, Loss on training: 1.9977, Accuracy: 0.4688
# Batch number: 076, Loss on training: 2.2176, Accuracy: 0.4062
# Batch number: 077, Loss on training: 1.5414, Accuracy: 0.5469
# Batch number: 078, Loss on training: 2.5612, Accuracy: 0.3594
# Batch number: 079, Loss on training: 1.7607, Accuracy: 0.5000
# Batch number: 080, Loss on training: 1.9369, Accuracy: 0.4844
# Batch number: 081, Loss on training: 1.8551, Accuracy: 0.4688
# Batch number: 082, Loss on training: 1.8755, Accuracy: 0.4844
# Batch number: 083, Loss on training: 2.3754, Accuracy: 0.3906
# Batch number: 084, Loss on training: 2.0981, Accuracy: 0.4375
# Batch number: 085, Loss on training: 1.7433, Accuracy: 0.5312
# Batch number: 086, Loss on training: 2.1033, Accuracy: 0.5156
# Batch number: 087, Loss on training: 2.5708, Accuracy: 0.3281
# Batch number: 088, Loss on training: 1.9896, Accuracy: 0.4375
# Batch number: 089, Loss on training: 2.2411, Accuracy: 0.4531
# Batch number: 090, Loss on training: 2.4207, Accuracy: 0.2969
# Batch number: 091, Loss on training: 2.0914, Accuracy: 0.3906
# Batch number: 092, Loss on training: 1.6544, Accuracy: 0.5312
# Batch number: 093, Loss on training: 2.1540, Accuracy: 0.4375
# Batch number: 094, Loss on training: 1.9059, Accuracy: 0.5312
# Batch number: 095, Loss on training: 1.7227, Accuracy: 0.5781
# Batch number: 096, Loss on training: 1.9325, Accuracy: 0.4531
# Batch number: 097, Loss on training: 2.2936, Accuracy: 0.4062
# Batch number: 098, Loss on training: 2.4001, Accuracy: 0.3125
# Batch number: 099, Loss on training: 1.6339, Accuracy: 0.4844
# Batch number: 100, Loss on training: 1.7766, Accuracy: 0.5469
# Batch number: 101, Loss on training: 1.8034, Accuracy: 0.4844
# Batch number: 102, Loss on training: 1.4840, Accuracy: 0.6250
# Epoch: 5/16
# Batch number: 000, Loss on training: 1.5552, Accuracy: 0.6406
# Batch number: 001, Loss on training: 2.0817, Accuracy: 0.4062
# Batch number: 002, Loss on training: 1.7765, Accuracy: 0.5000
# Batch number: 003, Loss on training: 2.5797, Accuracy: 0.3125
# Batch number: 004, Loss on training: 1.8823, Accuracy: 0.5000
# Batch number: 005, Loss on training: 2.0931, Accuracy: 0.4844
# Batch number: 006, Loss on training: 1.6728, Accuracy: 0.5156
# Batch number: 007, Loss on training: 1.6872, Accuracy: 0.5625
# Batch number: 008, Loss on training: 2.0296, Accuracy: 0.4531
# Batch number: 009, Loss on training: 1.7582, Accuracy: 0.4844
# Batch number: 010, Loss on training: 1.9291, Accuracy: 0.4375
# Batch number: 011, Loss on training: 1.5636, Accuracy: 0.5781
# Batch number: 012, Loss on training: 1.9626, Accuracy: 0.4688
# Batch number: 013, Loss on training: 1.8742, Accuracy: 0.4531
# Batch number: 014, Loss on training: 2.2880, Accuracy: 0.3438
# Batch number: 015, Loss on training: 2.2224, Accuracy: 0.3750
# Batch number: 016, Loss on training: 2.0061, Accuracy: 0.4531
# Batch number: 017, Loss on training: 1.7702, Accuracy: 0.5312
# Batch number: 018, Loss on training: 1.8570, Accuracy: 0.4375
# Batch number: 019, Loss on training: 2.4365, Accuracy: 0.3750
# Batch number: 020, Loss on training: 1.8687, Accuracy: 0.4375
# Batch number: 021, Loss on training: 1.6802, Accuracy: 0.5156
# Batch number: 022, Loss on training: 1.9715, Accuracy: 0.4375
# Batch number: 023, Loss on training: 1.7777, Accuracy: 0.5312
# Batch number: 024, Loss on training: 2.0847, Accuracy: 0.4219
# Batch number: 025, Loss on training: 2.1605, Accuracy: 0.4375
# Batch number: 026, Loss on training: 1.9621, Accuracy: 0.4531
# Batch number: 027, Loss on training: 1.9242, Accuracy: 0.4062
# Batch number: 028, Loss on training: 1.6921, Accuracy: 0.5469
# Batch number: 029, Loss on training: 2.1272, Accuracy: 0.4219
# Batch number: 030, Loss on training: 1.9436, Accuracy: 0.4531
# Batch number: 031, Loss on training: 2.1813, Accuracy: 0.4219
# Batch number: 032, Loss on training: 2.0925, Accuracy: 0.4219
# Batch number: 033, Loss on training: 1.5451, Accuracy: 0.6250
# Batch number: 034, Loss on training: 2.1352, Accuracy: 0.3750
# Batch number: 035, Loss on training: 1.6995, Accuracy: 0.5000
# Batch number: 036, Loss on training: 1.8129, Accuracy: 0.5000
# Batch number: 037, Loss on training: 2.0349, Accuracy: 0.4219
# Batch number: 038, Loss on training: 2.1555, Accuracy: 0.4062
# Batch number: 039, Loss on training: 2.4964, Accuracy: 0.3281
# Batch number: 040, Loss on training: 2.1149, Accuracy: 0.4062
# Batch number: 041, Loss on training: 1.9688, Accuracy: 0.4844
# Batch number: 042, Loss on training: 1.7774, Accuracy: 0.5000
# Batch number: 043, Loss on training: 1.8491, Accuracy: 0.5156
# Batch number: 044, Loss on training: 1.8275, Accuracy: 0.4844
# Batch number: 045, Loss on training: 1.9676, Accuracy: 0.4219
# Batch number: 046, Loss on training: 1.7605, Accuracy: 0.4688
# Batch number: 047, Loss on training: 1.6955, Accuracy: 0.4844
# Batch number: 048, Loss on training: 1.9756, Accuracy: 0.4844
# Batch number: 049, Loss on training: 2.1375, Accuracy: 0.4844
# Batch number: 050, Loss on training: 1.8518, Accuracy: 0.5781
# Batch number: 051, Loss on training: 1.9174, Accuracy: 0.4844
# Batch number: 052, Loss on training: 2.0513, Accuracy: 0.4375
# Batch number: 053, Loss on training: 1.7434, Accuracy: 0.4688
# Batch number: 054, Loss on training: 2.1286, Accuracy: 0.4375
# Batch number: 055, Loss on training: 1.8292, Accuracy: 0.4688
# Batch number: 056, Loss on training: 1.6923, Accuracy: 0.4688
# Batch number: 057, Loss on training: 2.2492, Accuracy: 0.4062
# Batch number: 058, Loss on training: 1.7694, Accuracy: 0.5469
# Batch number: 059, Loss on training: 1.7292, Accuracy: 0.4688
# Batch number: 060, Loss on training: 1.9052, Accuracy: 0.4531
# Batch number: 061, Loss on training: 1.9532, Accuracy: 0.5000
# Batch number: 062, Loss on training: 1.7671, Accuracy: 0.5000
# Batch number: 063, Loss on training: 1.9310, Accuracy: 0.5156
# Batch number: 064, Loss on training: 1.9161, Accuracy: 0.5156
# Batch number: 065, Loss on training: 1.9718, Accuracy: 0.4531
# Batch number: 066, Loss on training: 1.8044, Accuracy: 0.4688
# Batch number: 067, Loss on training: 2.1257, Accuracy: 0.4219
# Batch number: 068, Loss on training: 1.8943, Accuracy: 0.5000
# Batch number: 069, Loss on training: 1.8782, Accuracy: 0.4844
# Batch number: 070, Loss on training: 1.7366, Accuracy: 0.5938
# Batch number: 071, Loss on training: 1.9338, Accuracy: 0.5000
# Batch number: 072, Loss on training: 2.1627, Accuracy: 0.3906
# Batch number: 073, Loss on training: 1.7193, Accuracy: 0.5469
# Batch number: 074, Loss on training: 1.7025, Accuracy: 0.5000
# Batch number: 075, Loss on training: 2.1952, Accuracy: 0.4219
# Batch number: 076, Loss on training: 1.7763, Accuracy: 0.5312
# Batch number: 077, Loss on training: 2.1598, Accuracy: 0.4219
# Batch number: 078, Loss on training: 2.1393, Accuracy: 0.4219
# Batch number: 079, Loss on training: 1.7681, Accuracy: 0.5000
# Batch number: 080, Loss on training: 2.0375, Accuracy: 0.4062
# Batch number: 081, Loss on training: 1.7444, Accuracy: 0.5625
# Batch number: 082, Loss on training: 1.9386, Accuracy: 0.4688
# Batch number: 083, Loss on training: 1.8044, Accuracy: 0.4375
# Batch number: 084, Loss on training: 1.9240, Accuracy: 0.5000
# Batch number: 085, Loss on training: 1.7635, Accuracy: 0.4375
# Batch number: 086, Loss on training: 2.0864, Accuracy: 0.4219
# Batch number: 087, Loss on training: 1.9567, Accuracy: 0.4375
# Batch number: 088, Loss on training: 1.9085, Accuracy: 0.4844
# Batch number: 089, Loss on training: 2.0514, Accuracy: 0.4688
# Batch number: 090, Loss on training: 2.0155, Accuracy: 0.4844
# Batch number: 091, Loss on training: 2.4289, Accuracy: 0.3125
# Batch number: 092, Loss on training: 2.0102, Accuracy: 0.4844
# Batch number: 093, Loss on training: 1.9292, Accuracy: 0.4375
# Batch number: 094, Loss on training: 1.9114, Accuracy: 0.5625
# Batch number: 095, Loss on training: 1.7450, Accuracy: 0.5000
# Batch number: 096, Loss on training: 2.1176, Accuracy: 0.4688
# Batch number: 097, Loss on training: 1.3858, Accuracy: 0.5938
# Batch number: 098, Loss on training: 2.2534, Accuracy: 0.3594
# Batch number: 099, Loss on training: 1.9498, Accuracy: 0.5312
# Batch number: 100, Loss on training: 1.9413, Accuracy: 0.5156
# Batch number: 101, Loss on training: 1.8192, Accuracy: 0.4688
# Batch number: 102, Loss on training: 1.1462, Accuracy: 0.6250
# Epoch: 6/16
# Batch number: 000, Loss on training: 1.7744, Accuracy: 0.4375
# Batch number: 001, Loss on training: 1.9794, Accuracy: 0.4531
# Batch number: 002, Loss on training: 1.4243, Accuracy: 0.5625
# Batch number: 003, Loss on training: 1.6814, Accuracy: 0.5938
# Batch number: 004, Loss on training: 2.0574, Accuracy: 0.3750
# Batch number: 005, Loss on training: 1.7169, Accuracy: 0.5000
# Batch number: 006, Loss on training: 1.3210, Accuracy: 0.6562
# Batch number: 007, Loss on training: 1.9454, Accuracy: 0.5000
# Batch number: 008, Loss on training: 1.8854, Accuracy: 0.4375
# Batch number: 009, Loss on training: 2.0714, Accuracy: 0.4531
# Batch number: 010, Loss on training: 1.1025, Accuracy: 0.7344
# Batch number: 011, Loss on training: 1.7576, Accuracy: 0.5156
# Batch number: 012, Loss on training: 2.0781, Accuracy: 0.4375
# Batch number: 013, Loss on training: 1.7651, Accuracy: 0.5156
# Batch number: 014, Loss on training: 2.0844, Accuracy: 0.3438
# Batch number: 015, Loss on training: 1.7274, Accuracy: 0.5156
# Batch number: 016, Loss on training: 1.9258, Accuracy: 0.4688
# Batch number: 017, Loss on training: 1.9187, Accuracy: 0.4688
# Batch number: 018, Loss on training: 1.9565, Accuracy: 0.5000
# Batch number: 019, Loss on training: 1.7283, Accuracy: 0.4844
# Batch number: 020, Loss on training: 1.8054, Accuracy: 0.5156
# Batch number: 021, Loss on training: 1.8388, Accuracy: 0.5156
# Batch number: 022, Loss on training: 1.7884, Accuracy: 0.5000
# Batch number: 023, Loss on training: 1.3726, Accuracy: 0.6250
# Batch number: 024, Loss on training: 1.8465, Accuracy: 0.5156
# Batch number: 025, Loss on training: 1.8018, Accuracy: 0.4844
# Batch number: 026, Loss on training: 1.7763, Accuracy: 0.4844
# Batch number: 027, Loss on training: 1.4415, Accuracy: 0.6250
# Batch number: 028, Loss on training: 2.2493, Accuracy: 0.4219
# Batch number: 029, Loss on training: 1.8493, Accuracy: 0.4844
# Batch number: 030, Loss on training: 1.8800, Accuracy: 0.5625
# Batch number: 031, Loss on training: 1.6093, Accuracy: 0.5156
# Batch number: 032, Loss on training: 2.0949, Accuracy: 0.4375
# Batch number: 033, Loss on training: 1.6206, Accuracy: 0.4688
# Batch number: 034, Loss on training: 1.9420, Accuracy: 0.4375
# Batch number: 035, Loss on training: 1.8304, Accuracy: 0.4844
# Batch number: 036, Loss on training: 1.6756, Accuracy: 0.5625
# Batch number: 037, Loss on training: 1.9092, Accuracy: 0.5469
# Batch number: 038, Loss on training: 1.5875, Accuracy: 0.5469
# Batch number: 039, Loss on training: 1.3180, Accuracy: 0.6094
# Batch number: 040, Loss on training: 1.6395, Accuracy: 0.5781
# Batch number: 041, Loss on training: 1.9205, Accuracy: 0.4688
# Batch number: 042, Loss on training: 1.7742, Accuracy: 0.5312
# Batch number: 043, Loss on training: 1.3834, Accuracy: 0.6250
# Batch number: 044, Loss on training: 2.0019, Accuracy: 0.4531
# Batch number: 045, Loss on training: 1.9197, Accuracy: 0.4531
# Batch number: 046, Loss on training: 1.6025, Accuracy: 0.4844
# Batch number: 047, Loss on training: 1.8165, Accuracy: 0.4531
# Batch number: 048, Loss on training: 1.5458, Accuracy: 0.5781
# Batch number: 049, Loss on training: 1.5422, Accuracy: 0.5625
# Batch number: 050, Loss on training: 2.1824, Accuracy: 0.4062
# Batch number: 051, Loss on training: 1.9498, Accuracy: 0.5000
# Batch number: 052, Loss on training: 1.7156, Accuracy: 0.5625
# Batch number: 053, Loss on training: 1.9954, Accuracy: 0.4375
# Batch number: 054, Loss on training: 1.4712, Accuracy: 0.5625
# Batch number: 055, Loss on training: 1.8307, Accuracy: 0.5625
# Batch number: 056, Loss on training: 1.5093, Accuracy: 0.6094
# Batch number: 057, Loss on training: 1.5757, Accuracy: 0.5469
# Batch number: 058, Loss on training: 1.9550, Accuracy: 0.5000
# Batch number: 059, Loss on training: 2.1651, Accuracy: 0.4688
# Batch number: 060, Loss on training: 1.7022, Accuracy: 0.6250
# Batch number: 061, Loss on training: 1.7368, Accuracy: 0.5000
# Batch number: 062, Loss on training: 1.7398, Accuracy: 0.5312
# Batch number: 063, Loss on training: 1.7795, Accuracy: 0.4688
# Batch number: 064, Loss on training: 1.6393, Accuracy: 0.5781
# Batch number: 065, Loss on training: 1.8300, Accuracy: 0.4844
# Batch number: 066, Loss on training: 2.0610, Accuracy: 0.3906
# Batch number: 067, Loss on training: 1.4622, Accuracy: 0.6250
# Batch number: 068, Loss on training: 1.7354, Accuracy: 0.5312
# Batch number: 069, Loss on training: 1.7460, Accuracy: 0.5000
# Batch number: 070, Loss on training: 1.7368, Accuracy: 0.5781
# Batch number: 071, Loss on training: 1.9762, Accuracy: 0.4844
# Batch number: 072, Loss on training: 2.4051, Accuracy: 0.3438
# Batch number: 073, Loss on training: 2.0499, Accuracy: 0.4375
# Batch number: 074, Loss on training: 1.6179, Accuracy: 0.5312
# Batch number: 075, Loss on training: 1.6552, Accuracy: 0.5469
# Batch number: 076, Loss on training: 1.9562, Accuracy: 0.4062
# Batch number: 077, Loss on training: 1.4314, Accuracy: 0.5938
# Batch number: 078, Loss on training: 1.7920, Accuracy: 0.5000
# Batch number: 079, Loss on training: 2.0375, Accuracy: 0.4531
# Batch number: 080, Loss on training: 1.6004, Accuracy: 0.5625
# Batch number: 081, Loss on training: 1.7605, Accuracy: 0.4688
# Batch number: 082, Loss on training: 1.4892, Accuracy: 0.5625
# Batch number: 083, Loss on training: 1.9931, Accuracy: 0.5000
# Batch number: 084, Loss on training: 2.2978, Accuracy: 0.4375
# Batch number: 085, Loss on training: 1.7862, Accuracy: 0.4531
# Batch number: 086, Loss on training: 1.7910, Accuracy: 0.5156
# Batch number: 087, Loss on training: 1.8733, Accuracy: 0.4062
# Batch number: 088, Loss on training: 1.5047, Accuracy: 0.6094
# Batch number: 089, Loss on training: 1.6630, Accuracy: 0.5469
# Batch number: 090, Loss on training: 2.4137, Accuracy: 0.3281
# Batch number: 091, Loss on training: 1.6532, Accuracy: 0.5781
# Batch number: 092, Loss on training: 1.7584, Accuracy: 0.4531
# Batch number: 093, Loss on training: 1.6096, Accuracy: 0.5625
# Batch number: 094, Loss on training: 1.7394, Accuracy: 0.5000
# Batch number: 095, Loss on training: 1.8023, Accuracy: 0.4688
# Batch number: 096, Loss on training: 2.0629, Accuracy: 0.3906
# Batch number: 097, Loss on training: 1.7147, Accuracy: 0.5938
# Batch number: 098, Loss on training: 1.5677, Accuracy: 0.5781
# Batch number: 099, Loss on training: 1.7065, Accuracy: 0.4688
# Batch number: 100, Loss on training: 2.0092, Accuracy: 0.4375
# Batch number: 101, Loss on training: 2.2151, Accuracy: 0.4219
# Batch number: 102, Loss on training: 1.7442, Accuracy: 0.5833
# Epoch: 7/16
# Batch number: 000, Loss on training: 1.7455, Accuracy: 0.4844
# Batch number: 001, Loss on training: 1.9846, Accuracy: 0.3594
# Batch number: 002, Loss on training: 1.8804, Accuracy: 0.4219
# Batch number: 003, Loss on training: 1.7387, Accuracy: 0.5781
# Batch number: 004, Loss on training: 1.7684, Accuracy: 0.5000
# Batch number: 005, Loss on training: 1.5134, Accuracy: 0.5938
# Batch number: 006, Loss on training: 1.7909, Accuracy: 0.6094
# Batch number: 007, Loss on training: 1.9716, Accuracy: 0.4062
# Batch number: 008, Loss on training: 2.0644, Accuracy: 0.4844
# Batch number: 009, Loss on training: 1.8154, Accuracy: 0.4844
# Batch number: 010, Loss on training: 1.7447, Accuracy: 0.5312
# Batch number: 011, Loss on training: 1.3511, Accuracy: 0.6406
# Batch number: 012, Loss on training: 1.9792, Accuracy: 0.4531
# Batch number: 013, Loss on training: 1.6885, Accuracy: 0.5156
# Batch number: 014, Loss on training: 1.6638, Accuracy: 0.5938
# Batch number: 015, Loss on training: 1.9829, Accuracy: 0.5156
# Batch number: 016, Loss on training: 1.9931, Accuracy: 0.4531
# Batch number: 017, Loss on training: 2.0049, Accuracy: 0.3750
# Batch number: 018, Loss on training: 1.6935, Accuracy: 0.5625
# Batch number: 019, Loss on training: 1.3460, Accuracy: 0.6250
# Batch number: 020, Loss on training: 1.5140, Accuracy: 0.5469
# Batch number: 021, Loss on training: 1.7266, Accuracy: 0.4531
# Batch number: 022, Loss on training: 1.5467, Accuracy: 0.5000
# Batch number: 023, Loss on training: 1.8917, Accuracy: 0.5000
# Batch number: 024, Loss on training: 2.0174, Accuracy: 0.4688
# Batch number: 025, Loss on training: 1.8097, Accuracy: 0.4844
# Batch number: 026, Loss on training: 1.6825, Accuracy: 0.5156
# Batch number: 027, Loss on training: 1.8699, Accuracy: 0.4688
# Batch number: 028, Loss on training: 2.1350, Accuracy: 0.5000
# Batch number: 029, Loss on training: 1.7300, Accuracy: 0.5156
# Batch number: 030, Loss on training: 1.7586, Accuracy: 0.4844
# Batch number: 031, Loss on training: 1.9967, Accuracy: 0.5000
# Batch number: 032, Loss on training: 1.8799, Accuracy: 0.4688
# Batch number: 033, Loss on training: 1.6026, Accuracy: 0.5781
# Batch number: 034, Loss on training: 1.8135, Accuracy: 0.5625
# Batch number: 035, Loss on training: 1.5443, Accuracy: 0.5938
# Batch number: 036, Loss on training: 1.5999, Accuracy: 0.5312
# Batch number: 037, Loss on training: 1.8471, Accuracy: 0.5469
# Batch number: 038, Loss on training: 1.5980, Accuracy: 0.5625
# Batch number: 039, Loss on training: 1.7837, Accuracy: 0.5000
# Batch number: 040, Loss on training: 2.0658, Accuracy: 0.4531
# Batch number: 041, Loss on training: 1.6674, Accuracy: 0.5469
# Batch number: 042, Loss on training: 1.8429, Accuracy: 0.4688
# Batch number: 043, Loss on training: 2.0276, Accuracy: 0.4062
# Batch number: 044, Loss on training: 1.9848, Accuracy: 0.3906
# Batch number: 045, Loss on training: 1.6619, Accuracy: 0.4688
# Batch number: 046, Loss on training: 1.6599, Accuracy: 0.6094
# Batch number: 047, Loss on training: 1.7516, Accuracy: 0.4531
# Batch number: 048, Loss on training: 1.6804, Accuracy: 0.5000
# Batch number: 049, Loss on training: 1.6132, Accuracy: 0.5312
# Batch number: 050, Loss on training: 1.8217, Accuracy: 0.4375
# Batch number: 051, Loss on training: 2.0063, Accuracy: 0.4844
# Batch number: 052, Loss on training: 1.6885, Accuracy: 0.5312
# Batch number: 053, Loss on training: 1.8697, Accuracy: 0.4688
# Batch number: 054, Loss on training: 1.6587, Accuracy: 0.5625
# Batch number: 055, Loss on training: 1.6708, Accuracy: 0.5312
# Batch number: 056, Loss on training: 2.0006, Accuracy: 0.3906
# Batch number: 057, Loss on training: 1.8884, Accuracy: 0.5156
# Batch number: 058, Loss on training: 2.1166, Accuracy: 0.4375
# Batch number: 059, Loss on training: 2.0996, Accuracy: 0.4062
# Batch number: 060, Loss on training: 1.7960, Accuracy: 0.4062
# Batch number: 061, Loss on training: 1.7073, Accuracy: 0.5938
# Batch number: 062, Loss on training: 1.8172, Accuracy: 0.4688
# Batch number: 063, Loss on training: 1.7177, Accuracy: 0.5469
# Batch number: 064, Loss on training: 1.5779, Accuracy: 0.5469
# Batch number: 065, Loss on training: 1.7934, Accuracy: 0.4688
# Batch number: 066, Loss on training: 1.5678, Accuracy: 0.5781
# Batch number: 067, Loss on training: 1.6857, Accuracy: 0.5938
# Batch number: 068, Loss on training: 2.0227, Accuracy: 0.5312
# Batch number: 069, Loss on training: 1.8325, Accuracy: 0.5156
# Batch number: 070, Loss on training: 1.6489, Accuracy: 0.5312
# Batch number: 071, Loss on training: 1.3949, Accuracy: 0.5312
# Batch number: 072, Loss on training: 1.8038, Accuracy: 0.5312
# Batch number: 073, Loss on training: 1.2849, Accuracy: 0.6875
# Batch number: 074, Loss on training: 1.7455, Accuracy: 0.5625
# Batch number: 075, Loss on training: 1.5858, Accuracy: 0.5312
# Batch number: 076, Loss on training: 1.7994, Accuracy: 0.5312
# Batch number: 077, Loss on training: 1.5089, Accuracy: 0.5469
# Batch number: 078, Loss on training: 1.8989, Accuracy: 0.4375
# Batch number: 079, Loss on training: 2.0083, Accuracy: 0.4688
# Batch number: 080, Loss on training: 1.9606, Accuracy: 0.5000
# Batch number: 081, Loss on training: 1.7432, Accuracy: 0.5625
# Batch number: 082, Loss on training: 2.0640, Accuracy: 0.4062
# Batch number: 083, Loss on training: 1.8058, Accuracy: 0.4688
# Batch number: 084, Loss on training: 1.8500, Accuracy: 0.4219
# Batch number: 085, Loss on training: 2.2441, Accuracy: 0.4531
# Batch number: 086, Loss on training: 1.8596, Accuracy: 0.5312
# Batch number: 087, Loss on training: 1.2943, Accuracy: 0.5625
# Batch number: 088, Loss on training: 1.8188, Accuracy: 0.4531
# Batch number: 089, Loss on training: 1.8286, Accuracy: 0.5000
# Batch number: 090, Loss on training: 1.6509, Accuracy: 0.5000
# Batch number: 091, Loss on training: 1.6150, Accuracy: 0.5469
# Batch number: 092, Loss on training: 1.7692, Accuracy: 0.5469
# Batch number: 093, Loss on training: 1.6636, Accuracy: 0.4688
# Batch number: 094, Loss on training: 1.9853, Accuracy: 0.4531
# Batch number: 095, Loss on training: 1.8514, Accuracy: 0.4531
# Batch number: 096, Loss on training: 1.3951, Accuracy: 0.5312
# Batch number: 097, Loss on training: 1.5835, Accuracy: 0.5625
# Batch number: 098, Loss on training: 1.7295, Accuracy: 0.4844
# Batch number: 099, Loss on training: 1.6337, Accuracy: 0.5781
# Batch number: 100, Loss on training: 1.3917, Accuracy: 0.6094
# Batch number: 101, Loss on training: 1.4151, Accuracy: 0.5781
# Batch number: 102, Loss on training: 1.2896, Accuracy: 0.6250
# Epoch: 8/16
# Batch number: 000, Loss on training: 1.7840, Accuracy: 0.5469
# Batch number: 001, Loss on training: 1.9286, Accuracy: 0.4531
# Batch number: 002, Loss on training: 1.7561, Accuracy: 0.5156
# Batch number: 003, Loss on training: 1.3411, Accuracy: 0.6406
# Batch number: 004, Loss on training: 1.4147, Accuracy: 0.5469
# Batch number: 005, Loss on training: 1.3720, Accuracy: 0.6250
# Batch number: 006, Loss on training: 1.5374, Accuracy: 0.5938
# Batch number: 007, Loss on training: 1.6597, Accuracy: 0.5781
# Batch number: 008, Loss on training: 1.8390, Accuracy: 0.4688
# Batch number: 009, Loss on training: 1.8411, Accuracy: 0.5156
# Batch number: 010, Loss on training: 1.6852, Accuracy: 0.5469
# Batch number: 011, Loss on training: 1.6769, Accuracy: 0.6406
# Batch number: 012, Loss on training: 1.7866, Accuracy: 0.5938
# Batch number: 013, Loss on training: 1.2591, Accuracy: 0.6406
# Batch number: 014, Loss on training: 1.7717, Accuracy: 0.5469
# Batch number: 015, Loss on training: 1.7239, Accuracy: 0.4531
# Batch number: 016, Loss on training: 1.7711, Accuracy: 0.3906
# Batch number: 017, Loss on training: 1.7721, Accuracy: 0.4844
# Batch number: 018, Loss on training: 1.2436, Accuracy: 0.5938
# Batch number: 019, Loss on training: 1.5433, Accuracy: 0.5469
# Batch number: 020, Loss on training: 1.6935, Accuracy: 0.5625
# Batch number: 021, Loss on training: 1.5386, Accuracy: 0.5156
# Batch number: 022, Loss on training: 2.0176, Accuracy: 0.3750
# Batch number: 023, Loss on training: 1.7324, Accuracy: 0.5000
# Batch number: 024, Loss on training: 1.8470, Accuracy: 0.5312
# Batch number: 025, Loss on training: 1.2721, Accuracy: 0.5938
# Batch number: 026, Loss on training: 1.8528, Accuracy: 0.5781
# Batch number: 027, Loss on training: 1.4469, Accuracy: 0.6094
# Batch number: 028, Loss on training: 1.8573, Accuracy: 0.4688
# Batch number: 029, Loss on training: 1.7999, Accuracy: 0.4688
# Batch number: 030, Loss on training: 1.8554, Accuracy: 0.5000
# Batch number: 031, Loss on training: 1.1341, Accuracy: 0.6875
# Batch number: 032, Loss on training: 1.5713, Accuracy: 0.5156
# Batch number: 033, Loss on training: 1.6327, Accuracy: 0.5469
# Batch number: 034, Loss on training: 1.8845, Accuracy: 0.5000
# Batch number: 035, Loss on training: 1.5336, Accuracy: 0.5625
# Batch number: 036, Loss on training: 1.7038, Accuracy: 0.5000
# Batch number: 037, Loss on training: 1.9329, Accuracy: 0.5000
# Batch number: 038, Loss on training: 1.6363, Accuracy: 0.5000
# Batch number: 039, Loss on training: 1.7683, Accuracy: 0.5000
# Batch number: 040, Loss on training: 1.6745, Accuracy: 0.5625
# Batch number: 041, Loss on training: 1.6692, Accuracy: 0.4844
# Batch number: 042, Loss on training: 1.6431, Accuracy: 0.5469
# Batch number: 043, Loss on training: 1.6777, Accuracy: 0.5938
# Batch number: 044, Loss on training: 1.2363, Accuracy: 0.6562
# Batch number: 045, Loss on training: 1.9428, Accuracy: 0.4375
# Batch number: 046, Loss on training: 1.5307, Accuracy: 0.5781
# Batch number: 047, Loss on training: 1.3600, Accuracy: 0.6406
# Batch number: 048, Loss on training: 1.7915, Accuracy: 0.5156
# Batch number: 049, Loss on training: 1.7825, Accuracy: 0.5469
# Batch number: 050, Loss on training: 1.8018, Accuracy: 0.5000
# ...
# Batch number: 052, Loss on training: 1.3760, Accuracy: 0.6562
# Batch number: 053, Loss on training: 1.2839, Accuracy: 0.6094
# Batch number: 054, Loss on training: 1.6803, Accuracy: 0.5938
# Batch number: 055, Loss on training: 1.6068, Accuracy: 0.5312
# Batch number: 056, Loss on training: 1.3058, Accuracy: 0.6094
# Batch number: 057, Loss on training: 1.1201, Accuracy: 0.6562
# Batch number: 058, Loss on training: 1.7788, Accuracy: 0.5469
# Batch number: 059, Loss on training: 1.2345, Accuracy: 0.6406
# Batch number: 060, Loss on training: 1.3888, Accuracy: 0.6562
# Batch number: 061, Loss on training: 1.5649, Accuracy: 0.5625
# Batch number: 062, Loss on training: 1.3351, Accuracy: 0.5781
# Batch number: 063, Loss on training: 1.4975, Accuracy: 0.5469
# Batch number: 064, Loss on training: 1.4978, Accuracy: 0.5781
# Batch number: 065, Loss on training: 1.4679, Accuracy: 0.5625
# Batch number: 066, Loss on training: 1.1224, Accuracy: 0.6875
# Batch number: 067, Loss on training: 1.3719, Accuracy: 0.5938
# Batch number: 068, Loss on training: 1.5434, Accuracy: 0.5625
# Batch number: 069, Loss on training: 1.0815, Accuracy: 0.7031
# Batch number: 070, Loss on training: 1.6906, Accuracy: 0.5625
# Batch number: 071, Loss on training: 1.1612, Accuracy: 0.7188
# Batch number: 072, Loss on training: 1.1270, Accuracy: 0.6562
# Batch number: 073, Loss on training: 1.3006, Accuracy: 0.5938
# Batch number: 074, Loss on training: 1.4012, Accuracy: 0.5625
# Batch number: 075, Loss on training: 1.3262, Accuracy: 0.6406
# Batch number: 076, Loss on training: 1.6482, Accuracy: 0.5312
# Batch number: 077, Loss on training: 1.8786, Accuracy: 0.5312
# Batch number: 078, Loss on training: 1.5877, Accuracy: 0.5938
# Batch number: 079, Loss on training: 1.4871, Accuracy: 0.5938
# Batch number: 080, Loss on training: 1.3953, Accuracy: 0.5469
# Batch number: 081, Loss on training: 1.4754, Accuracy: 0.5781
# Batch number: 082, Loss on training: 1.4143, Accuracy: 0.5156
# Batch number: 083, Loss on training: 1.1174, Accuracy: 0.7031
# Batch number: 084, Loss on training: 1.5113, Accuracy: 0.6250
# Batch number: 085, Loss on training: 1.0867, Accuracy: 0.7188
# Batch number: 086, Loss on training: 1.5872, Accuracy: 0.6094
# Batch number: 087, Loss on training: 1.5154, Accuracy: 0.5938
# Batch number: 088, Loss on training: 1.4350, Accuracy: 0.5312
# Batch number: 089, Loss on training: 1.2285, Accuracy: 0.5625
# Batch number: 090, Loss on training: 1.4193, Accuracy: 0.5781
# Batch number: 091, Loss on training: 1.4135, Accuracy: 0.5625
# Batch number: 092, Loss on training: 1.1477, Accuracy: 0.6719
# Batch number: 093, Loss on training: 1.1189, Accuracy: 0.6875
# Batch number: 094, Loss on training: 1.2807, Accuracy: 0.6406
# Batch number: 095, Loss on training: 1.3257, Accuracy: 0.6875
# Batch number: 096, Loss on training: 1.4019, Accuracy: 0.5469
# Batch number: 097, Loss on training: 1.3561, Accuracy: 0.6719
# Batch number: 098, Loss on training: 1.5240, Accuracy: 0.6094
# Batch number: 099, Loss on training: 1.2197, Accuracy: 0.6562
# Batch number: 100, Loss on training: 1.5179, Accuracy: 0.5781
# Batch number: 101, Loss on training: 1.6209, Accuracy: 0.5469
# Batch number: 102, Loss on training: 1.8073, Accuracy: 0.5417
# Epoch: 15/16
# Batch number: 000, Loss on training: 1.2704, Accuracy: 0.6719
# Batch number: 001, Loss on training: 1.1182, Accuracy: 0.6719
# Batch number: 002, Loss on training: 1.4121, Accuracy: 0.5312
# Batch number: 003, Loss on training: 1.3220, Accuracy: 0.6250
# Batch number: 004, Loss on training: 1.2049, Accuracy: 0.6406
# Batch number: 005, Loss on training: 1.8778, Accuracy: 0.5312
# Batch number: 006, Loss on training: 1.4498, Accuracy: 0.5312
# Batch number: 007, Loss on training: 1.8417, Accuracy: 0.5000
# Batch number: 008, Loss on training: 1.5238, Accuracy: 0.5469
# Batch number: 009, Loss on training: 1.5137, Accuracy: 0.5469
# Batch number: 010, Loss on training: 1.8125, Accuracy: 0.5312
# Batch number: 011, Loss on training: 1.3547, Accuracy: 0.5938
# Batch number: 012, Loss on training: 1.6973, Accuracy: 0.5625
# Batch number: 013, Loss on training: 1.3540, Accuracy: 0.6562
# Batch number: 014, Loss on training: 1.7023, Accuracy: 0.5625
# Batch number: 015, Loss on training: 1.1960, Accuracy: 0.7031
# Batch number: 016, Loss on training: 1.0371, Accuracy: 0.6875
# Batch number: 017, Loss on training: 1.4688, Accuracy: 0.5938
# Batch number: 018, Loss on training: 1.3077, Accuracy: 0.6719
# Batch number: 019, Loss on training: 1.8520, Accuracy: 0.4688
# Batch number: 020, Loss on training: 1.6797, Accuracy: 0.5312
# Batch number: 021, Loss on training: 1.2702, Accuracy: 0.5938
# Batch number: 022, Loss on training: 1.6528, Accuracy: 0.5625
# Batch number: 023, Loss on training: 1.4131, Accuracy: 0.6562
# Batch number: 024, Loss on training: 1.7920, Accuracy: 0.5156
# Batch number: 025, Loss on training: 1.2790, Accuracy: 0.5781
# Batch number: 026, Loss on training: 1.4926, Accuracy: 0.5781
# Batch number: 027, Loss on training: 1.7562, Accuracy: 0.4844
# Batch number: 028, Loss on training: 1.8615, Accuracy: 0.4375
# Batch number: 029, Loss on training: 1.3538, Accuracy: 0.5469
# Batch number: 030, Loss on training: 1.5296, Accuracy: 0.5000
# Batch number: 031, Loss on training: 1.4770, Accuracy: 0.6250
# Batch number: 032, Loss on training: 1.3380, Accuracy: 0.5938
# Batch number: 033, Loss on training: 1.2588, Accuracy: 0.5938
# Batch number: 034, Loss on training: 0.9978, Accuracy: 0.7031
# Batch number: 035, Loss on training: 1.4753, Accuracy: 0.5781
# Batch number: 036, Loss on training: 1.8048, Accuracy: 0.5156
# Batch number: 037, Loss on training: 1.5303, Accuracy: 0.5781
# Batch number: 038, Loss on training: 1.2682, Accuracy: 0.6094
# Batch number: 039, Loss on training: 1.5157, Accuracy: 0.5312
# Batch number: 040, Loss on training: 1.5924, Accuracy: 0.5156
# Batch number: 041, Loss on training: 1.2144, Accuracy: 0.6562
# Batch number: 042, Loss on training: 1.1680, Accuracy: 0.6562
# Batch number: 043, Loss on training: 1.5216, Accuracy: 0.5469
# Batch number: 044, Loss on training: 1.3744, Accuracy: 0.6719
# Batch number: 045, Loss on training: 1.1024, Accuracy: 0.6094
# Batch number: 046, Loss on training: 1.4957, Accuracy: 0.5156
# Batch number: 047, Loss on training: 1.5633, Accuracy: 0.5625
# Batch number: 048, Loss on training: 1.7269, Accuracy: 0.5156
# Batch number: 049, Loss on training: 1.3240, Accuracy: 0.6719
# Batch number: 050, Loss on training: 1.1850, Accuracy: 0.6250
# Batch number: 051, Loss on training: 1.2018, Accuracy: 0.5781
# Batch number: 052, Loss on training: 1.6077, Accuracy: 0.5000
# Batch number: 053, Loss on training: 1.3517, Accuracy: 0.5938
# Batch number: 054, Loss on training: 1.3273, Accuracy: 0.5781
# Batch number: 055, Loss on training: 1.6259, Accuracy: 0.5781
# Batch number: 056, Loss on training: 2.0121, Accuracy: 0.4844
# Batch number: 057, Loss on training: 1.1857, Accuracy: 0.7188
# Batch number: 058, Loss on training: 1.5374, Accuracy: 0.5625
# Batch number: 059, Loss on training: 1.3164, Accuracy: 0.5938
# Batch number: 060, Loss on training: 1.2339, Accuracy: 0.5938
# Batch number: 061, Loss on training: 1.3248, Accuracy: 0.6406
# Batch number: 062, Loss on training: 1.4654, Accuracy: 0.6562
# Batch number: 063, Loss on training: 0.9758, Accuracy: 0.7188
# Batch number: 064, Loss on training: 1.1567, Accuracy: 0.7031
# Batch number: 065, Loss on training: 1.6034, Accuracy: 0.5156
# Batch number: 066, Loss on training: 1.0854, Accuracy: 0.6719
# Batch number: 067, Loss on training: 1.3357, Accuracy: 0.6250
# Batch number: 068, Loss on training: 1.8431, Accuracy: 0.5156
# Batch number: 069, Loss on training: 1.3480, Accuracy: 0.6406
# Batch number: 070, Loss on training: 1.6221, Accuracy: 0.5781
# Batch number: 071, Loss on training: 1.2279, Accuracy: 0.6094
# Batch number: 072, Loss on training: 1.1261, Accuracy: 0.6875
# Batch number: 073, Loss on training: 1.4519, Accuracy: 0.5625
# Batch number: 074, Loss on training: 1.3689, Accuracy: 0.5625
# Batch number: 075, Loss on training: 1.0682, Accuracy: 0.7344
# Batch number: 076, Loss on training: 1.2130, Accuracy: 0.6875
# Batch number: 077, Loss on training: 0.9985, Accuracy: 0.7031
# Batch number: 078, Loss on training: 1.3012, Accuracy: 0.6719
# Batch number: 079, Loss on training: 1.3006, Accuracy: 0.6094
# Batch number: 080, Loss on training: 1.3809, Accuracy: 0.6406
# Batch number: 081, Loss on training: 1.0672, Accuracy: 0.7188
# Batch number: 082, Loss on training: 1.1394, Accuracy: 0.6562
# Batch number: 083, Loss on training: 1.4485, Accuracy: 0.5781
# Batch number: 084, Loss on training: 1.6032, Accuracy: 0.5938
# Batch number: 085, Loss on training: 1.6392, Accuracy: 0.5469
# Batch number: 086, Loss on training: 1.1010, Accuracy: 0.7188
# Batch number: 087, Loss on training: 1.5480, Accuracy: 0.5938
# Batch number: 088, Loss on training: 1.1923, Accuracy: 0.6875
# Batch number: 089, Loss on training: 1.3567, Accuracy: 0.6094
# Batch number: 090, Loss on training: 1.4921, Accuracy: 0.5469
# Batch number: 091, Loss on training: 1.4718, Accuracy: 0.5312
# Batch number: 092, Loss on training: 1.4448, Accuracy: 0.5156
# Batch number: 093, Loss on training: 1.5200, Accuracy: 0.5938
# Batch number: 094, Loss on training: 1.3583, Accuracy: 0.5781
# Batch number: 095, Loss on training: 1.7258, Accuracy: 0.5469
# Batch number: 096, Loss on training: 1.4352, Accuracy: 0.6094
# Batch number: 097, Loss on training: 1.4539, Accuracy: 0.5938
# Batch number: 098, Loss on training: 1.3291, Accuracy: 0.6562
# Batch number: 099, Loss on training: 1.5214, Accuracy: 0.5938
# Batch number: 100, Loss on training: 1.4956, Accuracy: 0.5781
# Batch number: 101, Loss on training: 1.3453, Accuracy: 0.6094
# Batch number: 102, Loss on training: 1.2584, Accuracy: 0.6250
# Epoch: 16/16
# Batch number: 000, Loss on training: 1.0880, Accuracy: 0.7031
# Batch number: 001, Loss on training: 1.6068, Accuracy: 0.5000
# Batch number: 002, Loss on training: 1.2588, Accuracy: 0.5938
# Batch number: 003, Loss on training: 1.0908, Accuracy: 0.6406
# Batch number: 004, Loss on training: 1.0951, Accuracy: 0.6406
# Batch number: 005, Loss on training: 1.4675, Accuracy: 0.6094
# Batch number: 006, Loss on training: 1.1751, Accuracy: 0.6250
# Batch number: 007, Loss on training: 1.4790, Accuracy: 0.5469
# Batch number: 008, Loss on training: 1.4381, Accuracy: 0.6094
# Batch number: 009, Loss on training: 1.3014, Accuracy: 0.6250
# Batch number: 010, Loss on training: 1.8872, Accuracy: 0.4531
# Batch number: 011, Loss on training: 1.4822, Accuracy: 0.5312
# Batch number: 012, Loss on training: 1.6111, Accuracy: 0.5156
# Batch number: 013, Loss on training: 1.0729, Accuracy: 0.6719
# Batch number: 014, Loss on training: 1.1459, Accuracy: 0.6562
# Batch number: 015, Loss on training: 1.3216, Accuracy: 0.6406
# Batch number: 016, Loss on training: 1.3482, Accuracy: 0.6094
# Batch number: 017, Loss on training: 1.1954, Accuracy: 0.6406
# Batch number: 018, Loss on training: 1.3440, Accuracy: 0.5781
# Batch number: 019, Loss on training: 1.4850, Accuracy: 0.6250
# Batch number: 020, Loss on training: 1.5288, Accuracy: 0.5000
# Batch number: 021, Loss on training: 1.4399, Accuracy: 0.5938
# Batch number: 022, Loss on training: 1.2186, Accuracy: 0.6562
# Batch number: 023, Loss on training: 1.3548, Accuracy: 0.5938
# Batch number: 024, Loss on training: 1.3587, Accuracy: 0.6562
# Batch number: 025, Loss on training: 1.3906, Accuracy: 0.6250
# Batch number: 026, Loss on training: 1.0791, Accuracy: 0.6406
# Batch number: 027, Loss on training: 1.5473, Accuracy: 0.6094
# Batch number: 028, Loss on training: 1.2889, Accuracy: 0.6406
# Batch number: 029, Loss on training: 1.3752, Accuracy: 0.5625
# Batch number: 030, Loss on training: 1.0289, Accuracy: 0.7188
# Batch number: 031, Loss on training: 1.7358, Accuracy: 0.5156
# Batch number: 032, Loss on training: 1.4210, Accuracy: 0.5938
# Batch number: 033, Loss on training: 1.7490, Accuracy: 0.5000
# Batch number: 034, Loss on training: 1.5338, Accuracy: 0.6406
# Batch number: 035, Loss on training: 1.2125, Accuracy: 0.6719
# Batch number: 036, Loss on training: 1.3224, Accuracy: 0.6250
# Batch number: 037, Loss on training: 1.3444, Accuracy: 0.6406
# Batch number: 038, Loss on training: 1.2189, Accuracy: 0.6406
# Batch number: 039, Loss on training: 1.2179, Accuracy: 0.6562
# Batch number: 040, Loss on training: 1.2931, Accuracy: 0.7031
# Batch number: 041, Loss on training: 2.0764, Accuracy: 0.4219
# Batch number: 042, Loss on training: 1.5542, Accuracy: 0.5781
# Batch number: 043, Loss on training: 1.1663, Accuracy: 0.6094
# Batch number: 044, Loss on training: 1.6209, Accuracy: 0.5469
# Batch number: 045, Loss on training: 1.4656, Accuracy: 0.5781
# Batch number: 046, Loss on training: 1.8018, Accuracy: 0.5000
# Batch number: 047, Loss on training: 1.4955, Accuracy: 0.5938
# Batch number: 048, Loss on training: 1.7416, Accuracy: 0.5625
# Batch number: 049, Loss on training: 1.3257, Accuracy: 0.6094
# Batch number: 050, Loss on training: 1.3374, Accuracy: 0.5625
# Batch number: 051, Loss on training: 1.3353, Accuracy: 0.6250
# Batch number: 052, Loss on training: 1.2517, Accuracy: 0.6406
# Batch number: 053, Loss on training: 1.0951, Accuracy: 0.6875
# Batch number: 054, Loss on training: 1.1170, Accuracy: 0.7031
# Batch number: 055, Loss on training: 1.6670, Accuracy: 0.6250
# Batch number: 056, Loss on training: 1.3427, Accuracy: 0.6562
# Batch number: 057, Loss on training: 1.5958, Accuracy: 0.5469
# Batch number: 058, Loss on training: 1.6987, Accuracy: 0.5938
# Batch number: 059, Loss on training: 1.4547, Accuracy: 0.6719
# Batch number: 060, Loss on training: 1.4120, Accuracy: 0.5781
# Batch number: 061, Loss on training: 1.4243, Accuracy: 0.6094
# Batch number: 062, Loss on training: 1.4124, Accuracy: 0.6094
# Batch number: 063, Loss on training: 1.5592, Accuracy: 0.5781
# Batch number: 064, Loss on training: 1.2228, Accuracy: 0.7031
# Batch number: 065, Loss on training: 1.3601, Accuracy: 0.6250
# Batch number: 066, Loss on training: 1.1463, Accuracy: 0.7344
# Batch number: 067, Loss on training: 1.5857, Accuracy: 0.5781
# Batch number: 068, Loss on training: 1.5938, Accuracy: 0.5938
# Batch number: 069, Loss on training: 1.4571, Accuracy: 0.6250
# Batch number: 070, Loss on training: 1.0439, Accuracy: 0.7031
# Batch number: 071, Loss on training: 1.5431, Accuracy: 0.5156
# Batch number: 072, Loss on training: 1.3226, Accuracy: 0.6406
# Batch number: 073, Loss on training: 1.5151, Accuracy: 0.5625
# Batch number: 074, Loss on training: 1.4408, Accuracy: 0.6562
# Batch number: 075, Loss on training: 1.3694, Accuracy: 0.6094
# Batch number: 076, Loss on training: 1.7267, Accuracy: 0.5156
# Batch number: 077, Loss on training: 1.2083, Accuracy: 0.7031
# Batch number: 078, Loss on training: 1.3438, Accuracy: 0.5938
# Batch number: 079, Loss on training: 1.6745, Accuracy: 0.5625
# Batch number: 080, Loss on training: 1.2068, Accuracy: 0.5938
# Batch number: 081, Loss on training: 1.5280, Accuracy: 0.5781
# Batch number: 082, Loss on training: 1.4081, Accuracy: 0.6094
# Batch number: 083, Loss on training: 1.5353, Accuracy: 0.4688
# Batch number: 084, Loss on training: 0.9475, Accuracy: 0.7031
# Batch number: 085, Loss on training: 1.3261, Accuracy: 0.6094
# Batch number: 086, Loss on training: 1.1243, Accuracy: 0.7344
# Batch number: 087, Loss on training: 1.8872, Accuracy: 0.5312
# Batch number: 088, Loss on training: 1.6946, Accuracy: 0.6094
# Batch number: 089, Loss on training: 1.1391, Accuracy: 0.6250
# Batch number: 090, Loss on training: 1.8480, Accuracy: 0.5625
# Batch number: 091, Loss on training: 1.5831, Accuracy: 0.5781
# Batch number: 092, Loss on training: 1.1222, Accuracy: 0.6875
# Batch number: 093, Loss on training: 1.3192, Accuracy: 0.5938
# Batch number: 094, Loss on training: 1.3793, Accuracy: 0.6562
# Batch number: 095, Loss on training: 1.1768, Accuracy: 0.7188
# Batch number: 096, Loss on training: 1.5602, Accuracy: 0.5469
# Batch number: 097, Loss on training: 1.5503, Accuracy: 0.6094
# Batch number: 098, Loss on training: 1.1909, Accuracy: 0.6719
# Batch number: 099, Loss on training: 1.2607, Accuracy: 0.6719
# Batch number: 100, Loss on training: 1.5955, Accuracy: 0.6250
# Batch number: 101, Loss on training: 1.5892, Accuracy: 0.5625
# Batch number: 102, Loss on training: 1.0726, Accuracy: 0.6250

# %%
with torch.no_grad():
    model.eval()
    
    for j, (datas, target) in enumerate(valid_loader):
        datas = datas.to(device)
        target = target.to(device)
        
        outputs = model(datas)
        
        loss = criterion(outputs, target)
        
        valid_loss += loss.item() * datas.size(0)
        
        _, predictions = torch.max(outputs.data, 1)
        correct_counts = predictions.eq(target.data.view_as(predictions))
        
        batch_acc = torch.mean(correct_counts.type(torch.FloatTensor))
        
        valid_acc += batch_acc.item() * datas.size(0)
        
        print("Validation Number: {:03d}, Validation: Loss: {:.4f}, Accuracy: {:.4f}".format(j, loss.item(), batch_acc.item()))
# Out:
# Validation Number: 000, Validation: Loss: 0.6443, Accuracy: 0.8281
# Validation Number: 001, Validation: Loss: 0.5581, Accuracy: 0.8594
# Validation Number: 002, Validation: Loss: 0.6745, Accuracy: 0.7969
# Validation Number: 003, Validation: Loss: 0.7948, Accuracy: 0.7656
# Validation Number: 004, Validation: Loss: 0.5796, Accuracy: 0.8281
# Validation Number: 005, Validation: Loss: 0.8250, Accuracy: 0.8594
# Validation Number: 006, Validation: Loss: 0.4868, Accuracy: 0.8594
# Validation Number: 007, Validation: Loss: 0.5270, Accuracy: 0.8438
# Validation Number: 008, Validation: Loss: 0.3642, Accuracy: 0.9219
# Validation Number: 009, Validation: Loss: 0.6821, Accuracy: 0.7812
# Validation Number: 010, Validation: Loss: 0.5806, Accuracy: 0.8125
# Validation Number: 011, Validation: Loss: 0.6637, Accuracy: 0.8281
# Validation Number: 012, Validation: Loss: 0.6760, Accuracy: 0.8400

# %% [markdown]
# ## Testing your network
#
# It's good practice to test your trained network on test data, images the network has never seen either in training or validation. This will give you a good estimate for the model's performance on completely new images. Run the test images through the network and measure the accuracy, the same way you did validation. You should be able to reach around 70% accuracy on the test set if the model has been trained well.

# %%
# TODO: Do validation on the test set
correct = 0
total = 0
with torch.no_grad():
    model.eval()
    for data in train_loader:
        images, target = data
        images, target = images.to(device), target.to(device)
        outputs = model(images)
        _, predicted = torch.max(outputs.data, 1)
        total += target.size(0)
        correct += (predicted == target).sum().item()
        
print('Accuracy on testing images is: %d%%' % (100 * correct / total))
# Out:
# Accuracy on testing images is: 80%

# %% [markdown]
# ## Save the checkpoint
#
# Now that your network is trained, save the model so you can load it later for making predictions. You probably want to save other things such as the mapping of classes to indices which you get from one of the image datasets: `image_datasets['train'].class_to_idx`. You can attach this to the model as an attribute which makes inference easier later on.
#
# ```model.class_to_idx = image_datasets['train'].class_to_idx```
#
# Remember that you'll want to completely rebuild the model later so you can use it for inference. Make sure to include any information you need in the checkpoint. If you want to load the model and keep training, you'll want to save the number of epochs as well as the optimizer state, `optimizer.state_dict`. You'll likely want to use this trained model in the next part of the project, so best to save it now.

# %%
# TODO: Save the checkpoint 
model.class_to_idx = image_datasets['train'].class_to_idx
torch.save({'structure' :'vgg16',
            'hidden_layer1' :120, 
            'dropout' :0.5,
            'epochs' :num_epochs,
            'state_dict' :model.state_dict(),
            'class_to_idx' :model.class_to_idx,
            'optimizer':optimizer.state_dict()}, './checkpoint.pth')

#test to see if save checkpoint cell is running properly
print("test")
# Out:
# test

# %%
#checking if correct keys are mapped to checkpoint
model_dict = torch.load('./checkpoint.pth')
model_dict.keys()
# Out:
# dict_keys(['structure', 'hidden_layer1', 'dropout', 'epochs', 'state_dict', 'class_to_idx', 'optimizer'])

# %% [markdown]
# ## Loading the checkpoint
#
# At this point it's good to write a function that can load a checkpoint and rebuild the model. That way you can come back to this project and keep working on it without having to retrain the network.

# %%
# TODO: Write a function that loads a checkpoint and rebuilds the model
def loading_the_checkpoint(path='./checkpoint.pth'):
    checkpoint = torch.load('./checkpoint.pth')
    model=models.vgg16(pretrained=True)
    
    for param in model.parameters():
        param.requires_grad = False
        
    model.class_to_idx = checkpoint['class_to_idx']
    model.load_state_dict(checkpoint['state_dict'])
    return model

# %%
#checking if model has loaded properly
print(model)
# Out:
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace)
#     (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): ReLU(inplace)
#     (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU(inplace)
#     (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU(inplace)
#     (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (25): ReLU(inplace)
#     (26): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (27): ReLU(inplace)
#     (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (29): ReLU(inplace)
#     (30): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (inputs): Linear(in_features=25088, out_features=120, bias=True)
#     (relu1): ReLU()
#     (dropout): Dropout(p=0.5)
#     (hidden_layer1): Linear(in_features=120, out_features=90, bias=True)
#     (relu2): ReLU()
#     (hidden_layer2): Linear(in_features=90, out_features=70, bias=True)
#     (relu3): ReLU()
#     (hidden_layer3): Linear(in_features=70, out_features=102, bias=True)
#     (output): LogSoftmax()
#   )
# )

# %% [markdown]
# # Inference for classification
#
# Now you'll write a function to use a trained network for inference. That is, you'll pass an image into the network and predict the class of the flower in the image. Write a function called `predict` that takes an image and a model, then returns the top $K$ most likely classes along with the probabilities. It should look like
#
# ```python
# probs, classes = predict(image_path, model)
# print(probs)
# print(classes)
# > [ 0.01558163  0.01541934  0.01452626  0.01443549  0.01407339]
# > ['70', '3', '45', '62', '55']
# ```
#
# First you'll need to handle processing the input image such that it can be used in your network.
#
# ## Image Preprocessing
#
# You'll want to use `PIL` to load the image ([documentation](https://pillow.readthedocs.io/en/latest/reference/Image.html)). It's best to write a function that preprocesses the image so it can be used as input for the model. This function should process the images in the same manner used for training.
#
# First, resize the images where the shortest side is 256 pixels, keeping the aspect ratio. This can be done with the [`thumbnail`](http://pillow.readthedocs.io/en/3.1.x/reference/Image.html#PIL.Image.Image.thumbnail) or [`resize`](http://pillow.readthedocs.io/en/3.1.x/reference/Image.html#PIL.Image.Image.thumbnail) methods. Then you'll need to crop out the center 224x224 portion of the image.
#
# Color channels of images are typically encoded as integers 0-255, but the model expected floats 0-1. You'll need to convert the values. It's easiest with a Numpy array, which you can get from a PIL image like so `np_image = np.array(pil_image)`.
#
# As before, the network expects the images to be normalized in a specific way. For the means, it's `[0.485, 0.456, 0.406]` and for the standard deviations `[0.229, 0.224, 0.225]`. You'll want to subtract the means from each color channel, then divide by the standard deviation.
#
# And finally, PyTorch expects the color channel to be the first dimension but it's the third dimension in the PIL image and Numpy array. You can reorder dimensions using [`ndarray.transpose`](https://docs.scipy.org/doc/numpy-1.13.0/reference/generated/numpy.ndarray.transpose.html). The color channel needs to be first and retain the order of the other two dimensions.

# %%
def process_image(image):
    ''' Scales, crops, and normalizes a PIL image for a PyTorch model,
        returns an Numpy array
    '''
    
    # TODO: Process a PIL image for use in a PyTorch model
    img = PIL.Image.open(image)
    
    original_width, original_height = img.size
    
    if original_width < original_height:
        size=[256, 256**600]
    else:
        size=[256**600, 256]
        
    img.thumbnail(size)
    center = original_width/4, original_height/4
    left, top, right, bottom = center[0]-(244/2), center[1]-(244/2), center[0]+(244/2), center[1]+(244/2)
    img = img.crop((left, top, right, bottom))
    
    numpy_img = np.array(img)/255
    
    mean = [0.485, 0.456, 0.406]
    std = [0.229, 0.224, 0.225]
    numpy_img = (numpy_img-mean)/std
    
    numpy_img = numpy_img.transpose(2,0,1)
    return numpy_img

# %% [markdown]
# To check your work, the function below converts a PyTorch tensor and displays it in the notebook. If your `process_image` function works, running the output through this function should return the original image (except for the cropped out portions).

# %%
def imshow(image, ax=None, title=None):
    """Imshow for Tensor."""
    if ax is None:
        fig, ax = plt.subplots()
    
    # PyTorch tensors assume the color channel is the first dimension
    # but matplotlib assumes is the third dimension
    image = image.transpose((1, 2, 0))
    
    # Undo preprocessing
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    image = std * image + mean
    
    # Image needs to be clipped between 0 and 1 or it looks like noise when displayed
    image = np.clip(image, 0, 1)
    
    ax.imshow(image)
    
    return ax

# %% [markdown]
# ## Class Prediction
#
# Once you can get images in the correct format, it's time to write a function for making predictions with your model. A common practice is to predict the top 5 or so (usually called top-$K$) most probable classes. You'll want to calculate the class probabilities then find the $K$ largest values.
#
# To get the top $K$ largest values in a tensor use [`x.topk(k)`](http://pytorch.org/docs/master/torch.html#torch.topk). This method returns both the highest `k` probabilities and the indices of those probabilities corresponding to the classes. You need to convert from these indices to the actual class labels using `class_to_idx` which hopefully you added to the model or from an `ImageFolder` you used to load the data ([see here](#Save-the-checkpoint)). Make sure to invert the dictionary so you get a mapping from index to class as well.
#
# Again, this method should take a path to an image and a model checkpoint, then return the probabilities and classes.
#
# ```python
# probs, classes = predict(image_path, model)
# print(probs)
# print(classes)
# > [ 0.01558163  0.01541934  0.01452626  0.01443549  0.01407339]
# > ['70', '3', '45', '62', '55']
# ```

# %%
def predict(image_path, model, top_k=5):
    ''' Predict the class (or classes) of an image using a trained deep learning model.
    '''
    
    # TODO: Implement the code to predict the class from an image file
    model.to("cpu")
    model.eval();
    
    torch_image = torch.from_numpy(np.expand_dims(process_image(image_path),
                                                 axis=0)).type(torch.FloatTensor).to("cpu")
    log_probs = model.forward(torch_image)
    linear_probs = torch.exp(log_probs)
    top_probs, top_labels = linear_probs.topk(top_k)
    top_probs = np.array(top_probs.detach())[0]
    top_labels = np.array(top_labels.detach())[0]
    
    idx_to_class = {val: key for key, val in model.class_to_idx.items()}
    top_labels = [idx_to_class[lab] for lab in top_labels]
    top_flowers = [cat_to_name[lab] for lab in top_labels]
    
    return top_probs, top_labels, top_flowers

# %% [markdown]
# ## Sanity Checking
#
# Now that you can use a trained model for predictions, check to make sure it makes sense. Even if the testing accuracy is high, it's always good to check that there aren't obvious bugs. Use `matplotlib` to plot the probabilities for the top 5 classes as a bar graph, along with the input image. It should look like this:
#
# <img src='assets/inference_example.png' width=300px>
#
# You can convert from the class integer encoding to actual flower names with the `cat_to_name.json` file (should have been loaded earlier in the notebook). To show a PyTorch tensor as an image, use the `imshow` function defined above.

# %%
# TODO: Display an image along with the top 5 classes
image_path = "flowers/test/1/image_06743.jpg"

plt.figure(figsize = (6, 10))
ax = plt.subplot(2,1,1)

flower_num = image_path.split('/')[2]
title_ = cat_to_name[flower_num]

img = process_image(image_path)
imshow(img, ax, title = title_);

probs, labs, flowers = predict(image_path, model)

plt.subplot(2,1,2)
sns.barplot(x=probs, y=flowers, color=sns.color_palette()[0]);
plt.show()

# %%
image_path = "flowers/test/37/image_03734.jpg"

plt.figure(figsize = (6, 10))
ax = plt.subplot(2,1,1)

flower_num = image_path.split('/')[2]
title_ = cat_to_name[flower_num]

img = process_image(image_path)
imshow(img, ax, title = title_);

probs, labs, flowers = predict(image_path, model)

plt.subplot(2,1,2)
sns.barplot(x=probs, y=flowers, color=sns.color_palette()[0]);
plt.show()

# %% [markdown]
# <font color='red'>**Reminder for Workspace users:** If your network becomes very large when saved as a checkpoint, there might be issues with saving backups in your workspace. You should reduce the size of your hidden layers and train again.
#
# We strongly encourage you to delete these large interim files and directories before navigating to another page or closing the browser tab.</font>
